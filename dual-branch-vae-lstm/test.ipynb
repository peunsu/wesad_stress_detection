# %%
import json
from tqdm import tqdm
from itertools import product

# %%
grid = {
    'exp_name': [
        'vae-lstm-dual-ma',
        'vae-lstm-dual-linear',
        'vae-lstm-local-only',
    ],
    'window_size': [
        (576, 48),
        (288, 48),
        (288, 24),
        (144, 24),
        (72, 24)
    ],
    'fold_id': [0, 1, 2]
}
grid_prod = list(product(*grid.values()))
len(grid_prod)
# Out:
# 45

# %%
for exp_name, window_size, fold_id in tqdm(grid_prod, desc="Experiments"):
    with open('config.json', 'r', encoding='utf-8') as f:
        config = json.load(f)
    config['exp_name'] = exp_name
    config['window_size'] = window_size[0]
    config['small_window_size'] = window_size[1]
    config['fold_id'] = fold_id
    config['window_shift'] = 1
    config['latent_dim'] = 12
    config['batch_size'] = 512
    json.dump(config, open('config.json', 'w', encoding='utf-8'), indent=4)
    
    # !python test.py --config config.json
# Out:
# Experiments:   0%|          | 0/45 [00:00<?, ?it/s]
# Using device: cuda:0
# Traceback (most recent call last):
#   File "/home/peunsu/ml_project/dual-branch-vae-lstm/test.py", line 263, in <module>
#     main()
#   File "/home/peunsu/ml_project/dual-branch-vae-lstm/test.py", line 172, in main
#     raise RuntimeError("No checkpoint found to load.")
# RuntimeError: No checkpoint found to load.
# Experiments:   2%|▏         | 1/45 [00:02<01:48,  2.46s/it]
# Using device: cuda:0
# Traceback (most recent call last):
#   File "/home/peunsu/ml_project/dual-branch-vae-lstm/test.py", line 263, in <module>
#     main()
#   File "/home/peunsu/ml_project/dual-branch-vae-lstm/test.py", line 172, in main
#     raise RuntimeError("No checkpoint found to load.")
# RuntimeError: No checkpoint found to load.
# Experiments:   4%|▍         | 2/45 [00:04<01:44,  2.43s/it]
# Using device: cuda:0
# Traceback (most recent call last):
#   File "/home/peunsu/ml_project/dual-branch-vae-lstm/test.py", line 263, in <module>
#     main()
#   File "/home/peunsu/ml_project/dual-branch-vae-lstm/test.py", line 172, in main
#     raise RuntimeError("No checkpoint found to load.")
# RuntimeError: No checkpoint found to load.
# Experiments:   7%|▋         | 3/45 [00:07<01:40,  2.38s/it]
# Using device: cuda:0
# Traceback (most recent call last):
#   File "/home/peunsu/ml_project/dual-branch-vae-lstm/test.py", line 263, in <module>
#     main()
#   File "/home/peunsu/ml_project/dual-branch-vae-lstm/test.py", line 172, in main
#     raise RuntimeError("No checkpoint found to load.")
# RuntimeError: No checkpoint found to load.
# Experiments:   9%|▉         | 4/45 [00:09<01:36,  2.35s/it]
# Exception ignored in: <module 'collections.abc' from '/usr/lib/python3.10/collections/abc.py'>
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
# KeyboardInterrupt:
# <frozen importlib._bootstrap>:241: RuntimeWarning: Cython module failed to patch module with custom type
# ^C
# Traceback (most recent call last):
#   File "/home/peunsu/ml_project/dual-branch-vae-lstm/test.py", line 4, in <module>
#     import pandas as pd
#   File "/home/peunsu/ml_project/venv/lib/python3.10/site-packages/pandas/__init__.py", line 49, in <module>
#     from pandas.core.api import (
#   File "/home/peunsu/ml_project/venv/lib/python3.10/site-packages/pandas/core/api.py", line 28, in <module>
#     from pandas.core.arrays import Categorical
#   File "/home/peunsu/ml_project/venv/lib/python3.10/site-packages/pandas/core/arrays/__init__.py", line 9, in <module>
#     from pandas.core.arrays.datetimes import DatetimeArray
#   File "/home/peunsu/ml_project/venv/lib/python3.10/site-packages/pandas/core/arrays/datetimes.py", line 17, in <module>
#     from pandas._config import using_string_dtype
#   File "<frozen importlib._bootstrap>", line 1053, in _handle_fromlist
# KeyboardInterrupt
# Experiments:  11%|█         | 5/45 [00:09<01:04,  1.60s/it]
# Using device: cuda:0
# Traceback (most recent call last):
#   File "/home/peunsu/ml_project/dual-branch-vae-lstm/test.py", line 263, in <module>
#     main()
#   File "/home/peunsu/ml_project/dual-branch-vae-lstm/test.py", line 172, in main
#     raise RuntimeError("No checkpoint found to load.")
# RuntimeError: No checkpoint found to load.
# Experiments:  13%|█▎        | 6/45 [00:12<01:12,  1.87s/it]
# Using device: cuda:0
# Traceback (most recent call last):
#   File "/home/peunsu/ml_project/dual-branch-vae-lstm/test.py", line 263, in <module>
#     main()
#   File "/home/peunsu/ml_project/dual-branch-vae-lstm/test.py", line 172, in main
#     raise RuntimeError("No checkpoint found to load.")
# RuntimeError: No checkpoint found to load.
# Experiments:  16%|█▌        | 7/45 [00:14<01:17,  2.04s/it]
# Using device: cuda:0
# Traceback (most recent call last):
#   File "/home/peunsu/ml_project/dual-branch-vae-lstm/test.py", line 263, in <module>
#     main()
#   File "/home/peunsu/ml_project/dual-branch-vae-lstm/test.py", line 172, in main
#     raise RuntimeError("No checkpoint found to load.")
# RuntimeError: No checkpoint found to load.
# Experiments:  18%|█▊        | 8/45 [00:16<01:20,  2.17s/it]
# Using device: cuda:0
# Traceback (most recent call last):
#   File "/home/peunsu/ml_project/dual-branch-vae-lstm/test.py", line 263, in <module>
#     main()
#   File "/home/peunsu/ml_project/dual-branch-vae-lstm/test.py", line 172, in main
#     raise RuntimeError("No checkpoint found to load.")
# RuntimeError: No checkpoint found to load.
# Experiments:  20%|██        | 9/45 [00:19<01:20,  2.24s/it]
# Using device: cuda:0

# %%
grid = {
    'exp_name': [
        'ma-vae',
    ],
    'window_size': [
        (576, 48),
        (288, 48),
        (288, 24),
        (144, 24),
        (72, 24)
    ],
    'fold_id': [0, 1, 2]
}
grid_prod = list(product(*grid.values()))
len(grid_prod)

# %%
for exp_name, window_size, fold_id in tqdm(grid_prod, desc="Experiments"):
    with open('config.json', 'r', encoding='utf-8') as f:
        config = json.load(f)
    config['exp_name'] = exp_name
    config['window_size'] = window_size[0]
    config['small_window_size'] = window_size[0]
    config['window_shift'] = window_size[1]
    config['fold_id'] = fold_id
    config['latent_dim'] = 64
    config['batch_size'] = 64
    json.dump(config, open('config.json', 'w', encoding='utf-8'), indent=4)

    # !python test.py --config config.json
