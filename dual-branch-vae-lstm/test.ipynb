# %%
import json
from tqdm import tqdm
from itertools import product

# %%
grid = {
    'exp_name': [
        'vae-lstm-dual-ma',
        'vae-lstm-dual-linear',
        'vae-lstm-local-only',
    ],
    'window_size': [
        (576, 48),
        (288, 48),
        (288, 24),
        (144, 24),
        (72, 24)
    ],
    'fold_id': [0, 1, 2]
}
grid_prod = list(product(*grid.values()))
len(grid_prod)
# Out:
# 45

# %%
for exp_name, window_size, fold_id in tqdm(grid_prod, desc="Experiments"):
    with open('config.json', 'r', encoding='utf-8') as f:
        config = json.load(f)
    config['exp_name'] = exp_name
    config['window_size'] = window_size[0]
    config['small_window_size'] = window_size[1]
    config['fold_id'] = fold_id
    config['window_shift'] = 1
    config['latent_dim'] = 12
    config['batch_size'] = 512
    json.dump(config, open('config.json', 'w', encoding='utf-8'), indent=4)
    
    # !python test.py --config config.json
# Out:
# Experiments:   0%|          | 0/45 [00:00<?, ?it/s]
# Using device: cuda:0
# Loaded VAE checkpoint: experiments/vae-lstm-dual-ma/fold-0-batch-512/vae-lstm-dual-ma-576-48-1-12/checkpoint/vae_checkpoint_epoch_99.pth
# VAE_LSTM_MA(
#   (encoder): VAE_Encoder(
#     (local_module): LocalModule(
#       (enc_conv1): Sequential(
#         (0): Conv2d(55, 64, kernel_size=(3, 1), stride=(2, 1), padding=(1, 0))
#         (1): LeakyReLU(negative_slope=0.2)
#       )
#       (enc_conv2): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(3, 1), stride=(2, 1), padding=(1, 0))
#         (1): LeakyReLU(negative_slope=0.2)
#       )
#       (enc_conv3): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(3, 1), stride=(2, 1), padding=(1, 0))
#         (1): LeakyReLU(negative_slope=0.2)
#       )
#       (enc_conv4): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(6, 1), stride=(1, 1))
#         (1): LeakyReLU(negative_slope=0.2)
#       )
#       (enc_fc): Sequential(
#         (0): Linear(in_features=512, out_features=48, bias=True)
#         (1): LeakyReLU(negative_slope=0.2)
#       )
#     )
#     (global_module): GlobalModule(
#       (enc_conv1): Sequential(
#         (0): Conv1d(55, 64, kernel_size=(7,), stride=(3,), padding=(3,))
#         (1): LeakyReLU(negative_slope=0.2)
#         (2): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       )
#       (enc_conv2): Sequential(
#         (0): Conv1d(64, 128, kernel_size=(5,), stride=(3,), padding=(2,))
#         (1): LeakyReLU(negative_slope=0.2)
#         (2): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       )
#       (enc_conv3): Sequential(
#         (0): Conv1d(128, 256, kernel_size=(3,), stride=(2,), padding=(1,))
#         (1): LeakyReLU(negative_slope=0.2)
#         (2): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       )
#       (enc_conv4): Sequential(
#         (0): Conv1d(256, 512, kernel_size=(3,), stride=(2,), padding=(1,))
#         (1): LeakyReLU(negative_slope=0.2)
#         (2): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       )
#       (enc_fc): Sequential(
#         (0): Linear(in_features=512, out_features=48, bias=True)
#         (1): LeakyReLU(negative_slope=0.2)
#       )
#     )
#     (ma): MA(
#       (ma_attn): MultiheadAttention(
#         (out_proj): NonDynamicallyQuantizableLinear(in_features=48, out_features=48, bias=True)
#       )
#       (ma_layernorm): LayerNorm((48,), eps=1e-05, elementwise_affine=True)
#     )
#     (fc_mean): Linear(in_features=48, out_features=12, bias=True)
#     (fc_log_var): Linear(in_features=48, out_features=12, bias=True)
#   )
#   (decoder): VAE_Decoder(
#     (dec_fc): Linear(in_features=12, out_features=512, bias=True)
#     (dec_conv1): Sequential(
#       (0): Conv2d(512, 768, kernel_size=(1, 1), stride=(1, 1))
#       (1): LeakyReLU(negative_slope=0.2)
#     )
#     (dec_conv2): Sequential(
#       (0): Conv2d(256, 256, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0))
#       (1): LeakyReLU(negative_slope=0.2)
#     )
#     (dec_conv3): Sequential(
#       (0): Conv2d(128, 128, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0))
#       (1): LeakyReLU(negative_slope=0.2)
#     )
#     (dec_conv4): Sequential(
#       (0): Conv2d(32, 32, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0))
#       (1): LeakyReLU(negative_slope=0.2)
#     )
#     (dec_out): Conv2d(16, 55, kernel_size=(5, 1), stride=(1, 1), padding=(2, 0))
#   )
#   (lstm): LSTMModel(
#     (lstm1): LSTM(12, 64, batch_first=True)
#     (lstm2): LSTM(64, 64, batch_first=True)
#     (lstm3): LSTM(64, 12, batch_first=True)
#   )
# )
# The model has 2,250,175 trainable parameters
# Evaluating on test set...
# Evaluating: 100%|███████████████████████████████| 84/84 [00:03<00:00, 23.46it/s]
# Test Set Inference Time: 1113.33 ms
# Finding the theoretical best threshold based on F1 score...
# 101it [00:50,  2.02it/s]
# Threshold: 42201.39609375
# Precision: 0.7493403693931399
# Recall: 1.0
# Accuracy: 0.8781056806252188
# F1: 0.856711915535445
# TP: 15620
# TN: 22020
# FP: 5225
# FN: 0
# ==================================================
# Evaluating completed successfully!
# ==================================================
# Experiments:   2%|▏         | 1/45 [00:56<41:41, 56.85s/it]
# Using device: cuda:0
# Loaded VAE checkpoint: experiments/vae-lstm-dual-ma/fold-1-batch-512/vae-lstm-dual-ma-576-48-1-12/checkpoint/vae_checkpoint_epoch_99.pth
# VAE_LSTM_MA(
#   (encoder): VAE_Encoder(
#     (local_module): LocalModule(
#       (enc_conv1): Sequential(
#         (0): Conv2d(55, 64, kernel_size=(3, 1), stride=(2, 1), padding=(1, 0))
#         (1): LeakyReLU(negative_slope=0.2)
#       )
#       (enc_conv2): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(3, 1), stride=(2, 1), padding=(1, 0))
#         (1): LeakyReLU(negative_slope=0.2)
#       )
#       (enc_conv3): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(3, 1), stride=(2, 1), padding=(1, 0))
#         (1): LeakyReLU(negative_slope=0.2)
#       )
#       (enc_conv4): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(6, 1), stride=(1, 1))
#         (1): LeakyReLU(negative_slope=0.2)
#       )
#       (enc_fc): Sequential(
#         (0): Linear(in_features=512, out_features=48, bias=True)
#         (1): LeakyReLU(negative_slope=0.2)
#       )
#     )
#     (global_module): GlobalModule(
#       (enc_conv1): Sequential(
#         (0): Conv1d(55, 64, kernel_size=(7,), stride=(3,), padding=(3,))
#         (1): LeakyReLU(negative_slope=0.2)
#         (2): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       )
#       (enc_conv2): Sequential(
#         (0): Conv1d(64, 128, kernel_size=(5,), stride=(3,), padding=(2,))
#         (1): LeakyReLU(negative_slope=0.2)
#         (2): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       )
#       (enc_conv3): Sequential(
#         (0): Conv1d(128, 256, kernel_size=(3,), stride=(2,), padding=(1,))
#         (1): LeakyReLU(negative_slope=0.2)
#         (2): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       )
#       (enc_conv4): Sequential(
#         (0): Conv1d(256, 512, kernel_size=(3,), stride=(2,), padding=(1,))
#         (1): LeakyReLU(negative_slope=0.2)
#         (2): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       )
#       (enc_fc): Sequential(
#         (0): Linear(in_features=512, out_features=48, bias=True)
#         (1): LeakyReLU(negative_slope=0.2)
#       )
#     )
#     (ma): MA(
#       (ma_attn): MultiheadAttention(
#         (out_proj): NonDynamicallyQuantizableLinear(in_features=48, out_features=48, bias=True)
#       )
#       (ma_layernorm): LayerNorm((48,), eps=1e-05, elementwise_affine=True)
#     )
#     (fc_mean): Linear(in_features=48, out_features=12, bias=True)
#     (fc_log_var): Linear(in_features=48, out_features=12, bias=True)
#   )
#   (decoder): VAE_Decoder(
#     (dec_fc): Linear(in_features=12, out_features=512, bias=True)
#     (dec_conv1): Sequential(
#       (0): Conv2d(512, 768, kernel_size=(1, 1), stride=(1, 1))
#       (1): LeakyReLU(negative_slope=0.2)
#     )
#     (dec_conv2): Sequential(
#       (0): Conv2d(256, 256, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0))
#       (1): LeakyReLU(negative_slope=0.2)
#     )
#     (dec_conv3): Sequential(
#       (0): Conv2d(128, 128, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0))
#       (1): LeakyReLU(negative_slope=0.2)
#     )
#     (dec_conv4): Sequential(
#       (0): Conv2d(32, 32, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0))
#       (1): LeakyReLU(negative_slope=0.2)
#     )
#     (dec_out): Conv2d(16, 55, kernel_size=(5, 1), stride=(1, 1), padding=(2, 0))
#   )
#   (lstm): LSTMModel(
#     (lstm1): LSTM(12, 64, batch_first=True)
#     (lstm2): LSTM(64, 64, batch_first=True)
#     (lstm3): LSTM(64, 12, batch_first=True)
#   )
# )
# The model has 2,250,175 trainable parameters
# Evaluating on test set...
# Evaluating: 100%|███████████████████████████████| 86/86 [00:03<00:00, 24.59it/s]
# Test Set Inference Time: 988.54 ms
# Finding the theoretical best threshold based on F1 score...
# 101it [00:54,  1.86it/s]
# Threshold: 19314.61328125
# Precision: 0.9357884243241659
# Recall: 0.9778186274509804
# Accuracy: 0.9667814231321675
# F1: 0.9563419530758398
# TP: 15958
# TN: 26446
# FP: 1095
# FN: 362
# ==================================================
# Evaluating completed successfully!
# ==================================================
# Experiments:   4%|▍         | 2/45 [01:57<42:24, 59.18s/it]
# Using device: cuda:0
# Loaded VAE checkpoint: experiments/vae-lstm-dual-ma/fold-2-batch-512/vae-lstm-dual-ma-576-48-1-12/checkpoint/vae_checkpoint_epoch_99.pth
# VAE_LSTM_MA(
#   (encoder): VAE_Encoder(
#     (local_module): LocalModule(
#       (enc_conv1): Sequential(
#         (0): Conv2d(55, 64, kernel_size=(3, 1), stride=(2, 1), padding=(1, 0))
#         (1): LeakyReLU(negative_slope=0.2)
#       )
#       (enc_conv2): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(3, 1), stride=(2, 1), padding=(1, 0))
#         (1): LeakyReLU(negative_slope=0.2)
#       )
#       (enc_conv3): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(3, 1), stride=(2, 1), padding=(1, 0))
#         (1): LeakyReLU(negative_slope=0.2)
#       )
#       (enc_conv4): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(6, 1), stride=(1, 1))
#         (1): LeakyReLU(negative_slope=0.2)
#       )
#       (enc_fc): Sequential(
#         (0): Linear(in_features=512, out_features=48, bias=True)
#         (1): LeakyReLU(negative_slope=0.2)
#       )
#     )
#     (global_module): GlobalModule(
#       (enc_conv1): Sequential(
#         (0): Conv1d(55, 64, kernel_size=(7,), stride=(3,), padding=(3,))
#         (1): LeakyReLU(negative_slope=0.2)
#         (2): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       )
#       (enc_conv2): Sequential(
#         (0): Conv1d(64, 128, kernel_size=(5,), stride=(3,), padding=(2,))
#         (1): LeakyReLU(negative_slope=0.2)
#         (2): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       )
#       (enc_conv3): Sequential(
#         (0): Conv1d(128, 256, kernel_size=(3,), stride=(2,), padding=(1,))
#         (1): LeakyReLU(negative_slope=0.2)
#         (2): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       )
#       (enc_conv4): Sequential(
#         (0): Conv1d(256, 512, kernel_size=(3,), stride=(2,), padding=(1,))
#         (1): LeakyReLU(negative_slope=0.2)
#         (2): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       )
#       (enc_fc): Sequential(
#         (0): Linear(in_features=512, out_features=48, bias=True)
#         (1): LeakyReLU(negative_slope=0.2)
#       )
#     )
#     (ma): MA(
#       (ma_attn): MultiheadAttention(
#         (out_proj): NonDynamicallyQuantizableLinear(in_features=48, out_features=48, bias=True)
#       )
#       (ma_layernorm): LayerNorm((48,), eps=1e-05, elementwise_affine=True)
#     )
#     (fc_mean): Linear(in_features=48, out_features=12, bias=True)
#     (fc_log_var): Linear(in_features=48, out_features=12, bias=True)
#   )
#   (decoder): VAE_Decoder(
#     (dec_fc): Linear(in_features=12, out_features=512, bias=True)
#     (dec_conv1): Sequential(
#       (0): Conv2d(512, 768, kernel_size=(1, 1), stride=(1, 1))
#       (1): LeakyReLU(negative_slope=0.2)
#     )
#     (dec_conv2): Sequential(
#       (0): Conv2d(256, 256, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0))
#       (1): LeakyReLU(negative_slope=0.2)
#     )
#     (dec_conv3): Sequential(
#       (0): Conv2d(128, 128, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0))
#       (1): LeakyReLU(negative_slope=0.2)
#     )
#     (dec_conv4): Sequential(
#       (0): Conv2d(32, 32, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0))
#       (1): LeakyReLU(negative_slope=0.2)
#     )
#     (dec_out): Conv2d(16, 55, kernel_size=(5, 1), stride=(1, 1), padding=(2, 0))
#   )
#   (lstm): LSTMModel(
#     (lstm1): LSTM(12, 64, batch_first=True)
#     (lstm2): LSTM(64, 64, batch_first=True)
#     (lstm3): LSTM(64, 12, batch_first=True)
#   )
# )
# The model has 2,250,175 trainable parameters
# Evaluating on test set...
# Evaluating: 100%|███████████████████████████████| 87/87 [00:03<00:00, 24.67it/s]
# Test Set Inference Time: 1001.69 ms
# Finding the theoretical best threshold based on F1 score...
# 101it [00:52,  1.94it/s]
# Threshold: 31903.067968749998
# Precision: 0.7683194154488517
# Recall: 0.9206954781412221
# Accuracy: 0.8707566184296941
# F1: 0.8376340720930895
# TP: 14721
# TN: 23729
# FP: 4439
# FN: 1268
# ==================================================
# Evaluating completed successfully!
# ==================================================
# Experiments:   7%|▋         | 3/45 [02:56<41:14, 58.93s/it]
# Using device: cuda:0
# Loaded VAE checkpoint: experiments/vae-lstm-dual-ma/fold-0-batch-512/vae-lstm-dual-ma-288-48-1-12/checkpoint/vae_checkpoint_epoch_99.pth
# VAE_LSTM_MA(
#   (encoder): VAE_Encoder(
#     (local_module): LocalModule(
#       (enc_conv1): Sequential(
#         (0): Conv2d(55, 64, kernel_size=(3, 1), stride=(2, 1), padding=(1, 0))
#         (1): LeakyReLU(negative_slope=0.2)
#       )
#       (enc_conv2): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(3, 1), stride=(2, 1), padding=(1, 0))
#         (1): LeakyReLU(negative_slope=0.2)
#       )
#       (enc_conv3): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(3, 1), stride=(2, 1), padding=(1, 0))
#         (1): LeakyReLU(negative_slope=0.2)
#       )
#       (enc_conv4): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(6, 1), stride=(1, 1))
#         (1): LeakyReLU(negative_slope=0.2)
#       )
#       (enc_fc): Sequential(
#         (0): Linear(in_features=512, out_features=48, bias=True)
#         (1): LeakyReLU(negative_slope=0.2)
#       )
#     )
#     (global_module): GlobalModule(
#       (enc_conv1): Sequential(
#         (0): Conv1d(55, 64, kernel_size=(7,), stride=(3,), padding=(3,))
#         (1): LeakyReLU(negative_slope=0.2)
#         (2): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       )
#       (enc_conv2): Sequential(
#         (0): Conv1d(64, 128, kernel_size=(5,), stride=(3,), padding=(2,))
#         (1): LeakyReLU(negative_slope=0.2)
#         (2): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       )
#       (enc_conv3): Sequential(
#         (0): Conv1d(128, 256, kernel_size=(3,), stride=(2,), padding=(1,))
#         (1): LeakyReLU(negative_slope=0.2)
#         (2): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       )
#       (enc_conv4): Sequential(
#         (0): Conv1d(256, 512, kernel_size=(3,), stride=(1,), padding=(1,))
#         (1): LeakyReLU(negative_slope=0.2)
#         (2): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       )
#       (enc_fc): Sequential(
#         (0): Linear(in_features=512, out_features=48, bias=True)
#         (1): LeakyReLU(negative_slope=0.2)
#       )
#     )
#     (ma): MA(
#       (ma_attn): MultiheadAttention(
#         (out_proj): NonDynamicallyQuantizableLinear(in_features=48, out_features=48, bias=True)
#       )
#       (ma_layernorm): LayerNorm((48,), eps=1e-05, elementwise_affine=True)
#     )
#     (fc_mean): Linear(in_features=48, out_features=12, bias=True)
#     (fc_log_var): Linear(in_features=48, out_features=12, bias=True)
#   )
#   (decoder): VAE_Decoder(
#     (dec_fc): Linear(in_features=12, out_features=512, bias=True)
#     (dec_conv1): Sequential(
#       (0): Conv2d(512, 768, kernel_size=(1, 1), stride=(1, 1))
#       (1): LeakyReLU(negative_slope=0.2)
#     )
#     (dec_conv2): Sequential(
#       (0): Conv2d(256, 256, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0))
#       (1): LeakyReLU(negative_slope=0.2)
#     )
#     (dec_conv3): Sequential(
#       (0): Conv2d(128, 128, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0))
#       (1): LeakyReLU(negative_slope=0.2)
#     )
#     (dec_conv4): Sequential(
#       (0): Conv2d(32, 32, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0))
#       (1): LeakyReLU(negative_slope=0.2)
#     )
#     (dec_out): Conv2d(16, 55, kernel_size=(5, 1), stride=(1, 1), padding=(2, 0))
#   )
#   (lstm): LSTMModel(
#     (lstm1): LSTM(12, 64, batch_first=True)
#     (lstm2): LSTM(64, 64, batch_first=True)
#     (lstm3): LSTM(64, 12, batch_first=True)
#   )
# )
# The model has 2,250,175 trainable parameters
# Evaluating on test set...
# Evaluating: 100%|███████████████████████████████| 85/85 [00:01<00:00, 57.01it/s]
# Test Set Inference Time: 640.74 ms
# Finding the theoretical best threshold based on F1 score...
# 101it [00:26,  3.86it/s]
# Threshold: 25004.985625000005
# Precision: 0.9162706494682055
# Recall: 0.8566290550070522
# Accuracy: 0.9271661298171622
# F1: 0.8854466596202208
# TP: 12147
# TN: 27863
# FP: 1110
# FN: 2033
# ==================================================
# Evaluating completed successfully!
# ==================================================
# Experiments:   9%|▉         | 4/45 [03:26<32:35, 47.69s/it]
# Using device: cuda:0
# Loaded VAE checkpoint: experiments/vae-lstm-dual-ma/fold-1-batch-512/vae-lstm-dual-ma-288-48-1-12/checkpoint/vae_checkpoint_epoch_99.pth
# VAE_LSTM_MA(
#   (encoder): VAE_Encoder(
#     (local_module): LocalModule(
#       (enc_conv1): Sequential(
#         (0): Conv2d(55, 64, kernel_size=(3, 1), stride=(2, 1), padding=(1, 0))
#         (1): LeakyReLU(negative_slope=0.2)
#       )
#       (enc_conv2): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(3, 1), stride=(2, 1), padding=(1, 0))
#         (1): LeakyReLU(negative_slope=0.2)
#       )
#       (enc_conv3): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(3, 1), stride=(2, 1), padding=(1, 0))
#         (1): LeakyReLU(negative_slope=0.2)
#       )
#       (enc_conv4): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(6, 1), stride=(1, 1))
#         (1): LeakyReLU(negative_slope=0.2)
#       )
#       (enc_fc): Sequential(
#         (0): Linear(in_features=512, out_features=48, bias=True)
#         (1): LeakyReLU(negative_slope=0.2)
#       )
#     )
#     (global_module): GlobalModule(
#       (enc_conv1): Sequential(
#         (0): Conv1d(55, 64, kernel_size=(7,), stride=(3,), padding=(3,))
#         (1): LeakyReLU(negative_slope=0.2)
#         (2): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       )
#       (enc_conv2): Sequential(
#         (0): Conv1d(64, 128, kernel_size=(5,), stride=(3,), padding=(2,))
#         (1): LeakyReLU(negative_slope=0.2)
#         (2): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       )
#       (enc_conv3): Sequential(
#         (0): Conv1d(128, 256, kernel_size=(3,), stride=(2,), padding=(1,))
#         (1): LeakyReLU(negative_slope=0.2)
#         (2): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       )
#       (enc_conv4): Sequential(
#         (0): Conv1d(256, 512, kernel_size=(3,), stride=(1,), padding=(1,))
#         (1): LeakyReLU(negative_slope=0.2)
#         (2): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       )
#       (enc_fc): Sequential(
#         (0): Linear(in_features=512, out_features=48, bias=True)
#         (1): LeakyReLU(negative_slope=0.2)
#       )
#     )
#     (ma): MA(
#       (ma_attn): MultiheadAttention(
#         (out_proj): NonDynamicallyQuantizableLinear(in_features=48, out_features=48, bias=True)
#       )
#       (ma_layernorm): LayerNorm((48,), eps=1e-05, elementwise_affine=True)
#     )
#     (fc_mean): Linear(in_features=48, out_features=12, bias=True)
#     (fc_log_var): Linear(in_features=48, out_features=12, bias=True)
#   )
#   (decoder): VAE_Decoder(
#     (dec_fc): Linear(in_features=12, out_features=512, bias=True)
#     (dec_conv1): Sequential(
#       (0): Conv2d(512, 768, kernel_size=(1, 1), stride=(1, 1))
#       (1): LeakyReLU(negative_slope=0.2)
#     )
#     (dec_conv2): Sequential(
#       (0): Conv2d(256, 256, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0))
#       (1): LeakyReLU(negative_slope=0.2)
#     )
#     (dec_conv3): Sequential(
#       (0): Conv2d(128, 128, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0))
#       (1): LeakyReLU(negative_slope=0.2)
#     )
#     (dec_conv4): Sequential(
#       (0): Conv2d(32, 32, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0))
#       (1): LeakyReLU(negative_slope=0.2)
#     )
#     (dec_out): Conv2d(16, 55, kernel_size=(5, 1), stride=(1, 1), padding=(2, 0))
#   )
#   (lstm): LSTMModel(
#     (lstm1): LSTM(12, 64, batch_first=True)
#     (lstm2): LSTM(64, 64, batch_first=True)
#     (lstm3): LSTM(64, 12, batch_first=True)
#   )
# )
# The model has 2,250,175 trainable parameters
# Evaluating on test set...
# Evaluating: 100%|███████████████████████████████| 87/87 [00:01<00:00, 50.36it/s]
# Test Set Inference Time: 670.56 ms
# Finding the theoretical best threshold based on F1 score...
# 101it [00:27,  3.65it/s]
# Threshold: 8577.9013671875
# Precision: 0.8917765222849968
# Recall: 0.9547043010752688
# Accuracy: 0.9456839339509389
# F1: 0.9221681272314184
# TP: 14206
# TN: 27545
# FP: 1724
# FN: 674
# ==================================================
# Evaluating completed successfully!
# ==================================================
# Experiments:  11%|█         | 5/45 [03:58<28:04, 42.11s/it]
# Using device: cuda:0
# Loaded VAE checkpoint: experiments/vae-lstm-dual-ma/fold-2-batch-512/vae-lstm-dual-ma-288-48-1-12/checkpoint/vae_checkpoint_epoch_99.pth
# VAE_LSTM_MA(
#   (encoder): VAE_Encoder(
#     (local_module): LocalModule(
#       (enc_conv1): Sequential(
#         (0): Conv2d(55, 64, kernel_size=(3, 1), stride=(2, 1), padding=(1, 0))
#         (1): LeakyReLU(negative_slope=0.2)
#       )
#       (enc_conv2): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(3, 1), stride=(2, 1), padding=(1, 0))
#         (1): LeakyReLU(negative_slope=0.2)
#       )
#       (enc_conv3): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(3, 1), stride=(2, 1), padding=(1, 0))
#         (1): LeakyReLU(negative_slope=0.2)
#       )
#       (enc_conv4): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(6, 1), stride=(1, 1))
#         (1): LeakyReLU(negative_slope=0.2)
#       )
#       (enc_fc): Sequential(
#         (0): Linear(in_features=512, out_features=48, bias=True)
#         (1): LeakyReLU(negative_slope=0.2)
#       )
#     )
#     (global_module): GlobalModule(
#       (enc_conv1): Sequential(
#         (0): Conv1d(55, 64, kernel_size=(7,), stride=(3,), padding=(3,))
#         (1): LeakyReLU(negative_slope=0.2)
#         (2): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       )
#       (enc_conv2): Sequential(
#         (0): Conv1d(64, 128, kernel_size=(5,), stride=(3,), padding=(2,))
#         (1): LeakyReLU(negative_slope=0.2)
#         (2): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       )
#       (enc_conv3): Sequential(
#         (0): Conv1d(128, 256, kernel_size=(3,), stride=(2,), padding=(1,))
#         (1): LeakyReLU(negative_slope=0.2)
#         (2): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       )
#       (enc_conv4): Sequential(
#         (0): Conv1d(256, 512, kernel_size=(3,), stride=(1,), padding=(1,))
#         (1): LeakyReLU(negative_slope=0.2)
#         (2): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       )
#       (enc_fc): Sequential(
#         (0): Linear(in_features=512, out_features=48, bias=True)
#         (1): LeakyReLU(negative_slope=0.2)
#       )
#     )
#     (ma): MA(
#       (ma_attn): MultiheadAttention(
#         (out_proj): NonDynamicallyQuantizableLinear(in_features=48, out_features=48, bias=True)
#       )
#       (ma_layernorm): LayerNorm((48,), eps=1e-05, elementwise_affine=True)
#     )
#     (fc_mean): Linear(in_features=48, out_features=12, bias=True)
#     (fc_log_var): Linear(in_features=48, out_features=12, bias=True)
#   )
#   (decoder): VAE_Decoder(
#     (dec_fc): Linear(in_features=12, out_features=512, bias=True)
#     (dec_conv1): Sequential(
#       (0): Conv2d(512, 768, kernel_size=(1, 1), stride=(1, 1))
#       (1): LeakyReLU(negative_slope=0.2)
#     )
#     (dec_conv2): Sequential(
#       (0): Conv2d(256, 256, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0))
#       (1): LeakyReLU(negative_slope=0.2)
#     )
#     (dec_conv3): Sequential(
#       (0): Conv2d(128, 128, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0))
#       (1): LeakyReLU(negative_slope=0.2)
#     )
#     (dec_conv4): Sequential(
#       (0): Conv2d(32, 32, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0))
#       (1): LeakyReLU(negative_slope=0.2)
#     )
#     (dec_out): Conv2d(16, 55, kernel_size=(5, 1), stride=(1, 1), padding=(2, 0))
#   )
#   (lstm): LSTMModel(
#     (lstm1): LSTM(12, 64, batch_first=True)
#     (lstm2): LSTM(64, 64, batch_first=True)
#     (lstm3): LSTM(64, 12, batch_first=True)
#   )
# )
# The model has 2,250,175 trainable parameters
# Evaluating on test set...
# Evaluating: 100%|███████████████████████████████| 87/87 [00:01<00:00, 59.17it/s]
# Test Set Inference Time: 596.81 ms
# Finding the theoretical best threshold based on F1 score...
# 101it [00:26,  3.82it/s]
# Threshold: 10435.894843749995
# Precision: 0.7558146020413855
# Recall: 0.9133247961178136
# Accuracy: 0.8725615929800877
# F1: 0.8271378868339132
# TP: 13551
# TN: 25230
# FP: 4378
# FN: 1286
# ==================================================
# Evaluating completed successfully!
# ==================================================
# Experiments:  13%|█▎        | 6/45 [04:29<24:50, 38.21s/it]
# Using device: cuda:0
# Loaded VAE checkpoint: experiments/vae-lstm-dual-ma/fold-0-batch-512/vae-lstm-dual-ma-288-24-1-12/checkpoint/vae_checkpoint_epoch_99.pth
# VAE_LSTM_MA(
#   (encoder): VAE_Encoder(
#     (local_module): LocalModule(
#       (enc_conv1): Sequential(
#         (0): Conv2d(55, 64, kernel_size=(3, 1), stride=(2, 1), padding=(1, 0))
#         (1): LeakyReLU(negative_slope=0.2)
#       )
#       (enc_conv2): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(3, 1), stride=(2, 1), padding=(1, 0))
#         (1): LeakyReLU(negative_slope=0.2)
#       )
#       (enc_conv3): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(3, 1), stride=(2, 1), padding=(1, 0))
#         (1): LeakyReLU(negative_slope=0.2)
#       )
#       (enc_conv4): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(4, 1), stride=(1, 1))
#         (1): LeakyReLU(negative_slope=0.2)
#       )
#       (enc_fc): Sequential(
#         (0): Linear(in_features=512, out_features=48, bias=True)
#         (1): LeakyReLU(negative_slope=0.2)
#       )
#     )
#     (global_module): GlobalModule(
#       (enc_conv1): Sequential(
#         (0): Conv1d(55, 64, kernel_size=(7,), stride=(3,), padding=(3,))
#         (1): LeakyReLU(negative_slope=0.2)
#         (2): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       )
#       (enc_conv2): Sequential(
#         (0): Conv1d(64, 128, kernel_size=(5,), stride=(3,), padding=(2,))
#         (1): LeakyReLU(negative_slope=0.2)
#         (2): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       )
#       (enc_conv3): Sequential(
#         (0): Conv1d(128, 256, kernel_size=(3,), stride=(2,), padding=(1,))
#         (1): LeakyReLU(negative_slope=0.2)
#         (2): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       )
#       (enc_conv4): Sequential(
#         (0): Conv1d(256, 512, kernel_size=(3,), stride=(1,), padding=(1,))
#         (1): LeakyReLU(negative_slope=0.2)
#         (2): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       )
#       (enc_fc): Sequential(
#         (0): Linear(in_features=512, out_features=48, bias=True)
#         (1): LeakyReLU(negative_slope=0.2)
#       )
#     )
#     (ma): MA(
#       (ma_attn): MultiheadAttention(
#         (out_proj): NonDynamicallyQuantizableLinear(in_features=48, out_features=48, bias=True)
#       )
#       (ma_layernorm): LayerNorm((48,), eps=1e-05, elementwise_affine=True)
#     )
#     (fc_mean): Linear(in_features=48, out_features=12, bias=True)
#     (fc_log_var): Linear(in_features=48, out_features=12, bias=True)
#   )
#   (decoder): VAE_Decoder(
#     (dec_fc): Linear(in_features=12, out_features=512, bias=True)
#     (dec_conv1): Sequential(
#       (0): Conv2d(512, 384, kernel_size=(1, 1), stride=(1, 1))
#       (1): LeakyReLU(negative_slope=0.2)
#     )
#     (dec_conv2): Sequential(
#       (0): Conv2d(128, 128, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0))
#       (1): LeakyReLU(negative_slope=0.2)
#     )
#     (dec_conv3): Sequential(
#       (0): Conv2d(64, 64, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0))
#       (1): LeakyReLU(negative_slope=0.2)
#     )
#     (dec_conv4): Sequential(
#       (0): Conv2d(32, 32, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0))
#       (1): LeakyReLU(negative_slope=0.2)
#     )
#     (dec_out): Conv2d(16, 55, kernel_size=(5, 1), stride=(1, 1), padding=(2, 0))
#   )
#   (lstm): LSTMModel(
#     (lstm1): LSTM(12, 64, batch_first=True)
#     (lstm2): LSTM(64, 64, batch_first=True)
#     (lstm3): LSTM(64, 12, batch_first=True)
#   )
# )
# The model has 1,606,527 trainable parameters
# Evaluating on test set...
# Evaluating: 100%|███████████████████████████████| 85/85 [00:01<00:00, 56.07it/s]
# Test Set Inference Time: 651.39 ms
# Finding the theoretical best threshold based on F1 score...
# 101it [00:25,  3.95it/s]
# Threshold: 26596.36015624999
# Precision: 0.8996633489461359
# Recall: 0.8669252468265162
# Accuracy: 0.9245011934280352
# F1: 0.8829909495762103
# TP: 12293
# TN: 27602
# FP: 1371
# FN: 1887
# ==================================================
# Evaluating completed successfully!
# ==================================================
# Experiments:  16%|█▌        | 7/45 [04:59<22:29, 35.50s/it]
# Using device: cuda:0
# Loaded VAE checkpoint: experiments/vae-lstm-dual-ma/fold-1-batch-512/vae-lstm-dual-ma-288-24-1-12/checkpoint/vae_checkpoint_epoch_99.pth
# VAE_LSTM_MA(
#   (encoder): VAE_Encoder(
#     (local_module): LocalModule(
#       (enc_conv1): Sequential(
#         (0): Conv2d(55, 64, kernel_size=(3, 1), stride=(2, 1), padding=(1, 0))
#         (1): LeakyReLU(negative_slope=0.2)
#       )
#       (enc_conv2): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(3, 1), stride=(2, 1), padding=(1, 0))
#         (1): LeakyReLU(negative_slope=0.2)
#       )
#       (enc_conv3): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(3, 1), stride=(2, 1), padding=(1, 0))
#         (1): LeakyReLU(negative_slope=0.2)
#       )
#       (enc_conv4): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(4, 1), stride=(1, 1))
#         (1): LeakyReLU(negative_slope=0.2)
#       )
#       (enc_fc): Sequential(
#         (0): Linear(in_features=512, out_features=48, bias=True)
#         (1): LeakyReLU(negative_slope=0.2)
#       )
#     )
#     (global_module): GlobalModule(
#       (enc_conv1): Sequential(
#         (0): Conv1d(55, 64, kernel_size=(7,), stride=(3,), padding=(3,))
#         (1): LeakyReLU(negative_slope=0.2)
#         (2): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       )
#       (enc_conv2): Sequential(
#         (0): Conv1d(64, 128, kernel_size=(5,), stride=(3,), padding=(2,))
#         (1): LeakyReLU(negative_slope=0.2)
#         (2): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       )
#       (enc_conv3): Sequential(
#         (0): Conv1d(128, 256, kernel_size=(3,), stride=(2,), padding=(1,))
#         (1): LeakyReLU(negative_slope=0.2)
#         (2): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       )
#       (enc_conv4): Sequential(
#         (0): Conv1d(256, 512, kernel_size=(3,), stride=(1,), padding=(1,))
#         (1): LeakyReLU(negative_slope=0.2)
#         (2): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       )
#       (enc_fc): Sequential(
#         (0): Linear(in_features=512, out_features=48, bias=True)
#         (1): LeakyReLU(negative_slope=0.2)
#       )
#     )
#     (ma): MA(
#       (ma_attn): MultiheadAttention(
#         (out_proj): NonDynamicallyQuantizableLinear(in_features=48, out_features=48, bias=True)
#       )
#       (ma_layernorm): LayerNorm((48,), eps=1e-05, elementwise_affine=True)
#     )
#     (fc_mean): Linear(in_features=48, out_features=12, bias=True)
#     (fc_log_var): Linear(in_features=48, out_features=12, bias=True)
#   )
#   (decoder): VAE_Decoder(
#     (dec_fc): Linear(in_features=12, out_features=512, bias=True)
#     (dec_conv1): Sequential(
#       (0): Conv2d(512, 384, kernel_size=(1, 1), stride=(1, 1))
#       (1): LeakyReLU(negative_slope=0.2)
#     )
#     (dec_conv2): Sequential(
#       (0): Conv2d(128, 128, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0))
#       (1): LeakyReLU(negative_slope=0.2)
#     )
#     (dec_conv3): Sequential(
#       (0): Conv2d(64, 64, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0))
#       (1): LeakyReLU(negative_slope=0.2)
#     )
#     (dec_conv4): Sequential(
#       (0): Conv2d(32, 32, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0))
#       (1): LeakyReLU(negative_slope=0.2)
#     )
#     (dec_out): Conv2d(16, 55, kernel_size=(5, 1), stride=(1, 1), padding=(2, 0))
#   )
#   (lstm): LSTMModel(
#     (lstm1): LSTM(12, 64, batch_first=True)
#     (lstm2): LSTM(64, 64, batch_first=True)
#     (lstm3): LSTM(64, 12, batch_first=True)
#   )
# )
# The model has 1,606,527 trainable parameters
# Evaluating on test set...
# Evaluating: 100%|███████████████████████████████| 87/87 [00:01<00:00, 52.62it/s]
# Test Set Inference Time: 670.34 ms
# Finding the theoretical best threshold based on F1 score...
# 101it [00:27,  3.72it/s]
# Threshold: 9028.034921875002
# Precision: 0.8761349693251533
# Recall: 0.959744623655914
# Accuracy: 0.9407008086253369
# F1: 0.9160359204618346
# TP: 14281
# TN: 27250
# FP: 2019
# FN: 599
# ==================================================
# Evaluating completed successfully!
# ==================================================
# Experiments:  18%|█▊        | 8/45 [05:31<21:06, 34.23s/it]
# Using device: cuda:0
# Loaded VAE checkpoint: experiments/vae-lstm-dual-ma/fold-2-batch-512/vae-lstm-dual-ma-288-24-1-12/checkpoint/vae_checkpoint_epoch_99.pth
# VAE_LSTM_MA(
#   (encoder): VAE_Encoder(
#     (local_module): LocalModule(
#       (enc_conv1): Sequential(
#         (0): Conv2d(55, 64, kernel_size=(3, 1), stride=(2, 1), padding=(1, 0))
#         (1): LeakyReLU(negative_slope=0.2)
#       )
#       (enc_conv2): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(3, 1), stride=(2, 1), padding=(1, 0))
#         (1): LeakyReLU(negative_slope=0.2)
#       )
#       (enc_conv3): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(3, 1), stride=(2, 1), padding=(1, 0))
#         (1): LeakyReLU(negative_slope=0.2)
#       )
#       (enc_conv4): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(4, 1), stride=(1, 1))
#         (1): LeakyReLU(negative_slope=0.2)
#       )
#       (enc_fc): Sequential(
#         (0): Linear(in_features=512, out_features=48, bias=True)
#         (1): LeakyReLU(negative_slope=0.2)
#       )
#     )
#     (global_module): GlobalModule(
#       (enc_conv1): Sequential(
#         (0): Conv1d(55, 64, kernel_size=(7,), stride=(3,), padding=(3,))
#         (1): LeakyReLU(negative_slope=0.2)
#         (2): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       )
#       (enc_conv2): Sequential(
#         (0): Conv1d(64, 128, kernel_size=(5,), stride=(3,), padding=(2,))
#         (1): LeakyReLU(negative_slope=0.2)
#         (2): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       )
#       (enc_conv3): Sequential(
#         (0): Conv1d(128, 256, kernel_size=(3,), stride=(2,), padding=(1,))
#         (1): LeakyReLU(negative_slope=0.2)
#         (2): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       )
#       (enc_conv4): Sequential(
#         (0): Conv1d(256, 512, kernel_size=(3,), stride=(1,), padding=(1,))
#         (1): LeakyReLU(negative_slope=0.2)
#         (2): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       )
#       (enc_fc): Sequential(
#         (0): Linear(in_features=512, out_features=48, bias=True)
#         (1): LeakyReLU(negative_slope=0.2)
#       )
#     )
#     (ma): MA(
#       (ma_attn): MultiheadAttention(
#         (out_proj): NonDynamicallyQuantizableLinear(in_features=48, out_features=48, bias=True)
#       )
#       (ma_layernorm): LayerNorm((48,), eps=1e-05, elementwise_affine=True)
#     )
#     (fc_mean): Linear(in_features=48, out_features=12, bias=True)
#     (fc_log_var): Linear(in_features=48, out_features=12, bias=True)
#   )
#   (decoder): VAE_Decoder(
#     (dec_fc): Linear(in_features=12, out_features=512, bias=True)
#     (dec_conv1): Sequential(
#       (0): Conv2d(512, 384, kernel_size=(1, 1), stride=(1, 1))
#       (1): LeakyReLU(negative_slope=0.2)
#     )
#     (dec_conv2): Sequential(
#       (0): Conv2d(128, 128, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0))
#       (1): LeakyReLU(negative_slope=0.2)
#     )
#     (dec_conv3): Sequential(
#       (0): Conv2d(64, 64, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0))
#       (1): LeakyReLU(negative_slope=0.2)
#     )
#     (dec_conv4): Sequential(
#       (0): Conv2d(32, 32, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0))
#       (1): LeakyReLU(negative_slope=0.2)
#     )
#     (dec_out): Conv2d(16, 55, kernel_size=(5, 1), stride=(1, 1), padding=(2, 0))
#   )
#   (lstm): LSTMModel(
#     (lstm1): LSTM(12, 64, batch_first=True)
#     (lstm2): LSTM(64, 64, batch_first=True)
#     (lstm3): LSTM(64, 12, batch_first=True)
#   )
# )
# The model has 1,606,527 trainable parameters
# Evaluating on test set...
# Evaluating: 100%|███████████████████████████████| 87/87 [00:01<00:00, 52.32it/s]
# Test Set Inference Time: 640.61 ms
# Finding the theoretical best threshold based on F1 score...
# 101it [00:25,  3.89it/s]
# Threshold: 9168.834765625
# Precision: 0.7217979151615234
# Recall: 0.9427107905910899
# Accuracy: 0.8595792552593092
# F1: 0.8175946222417068
# TP: 13987
# TN: 24217
# FP: 5391
# FN: 850
# ==================================================
# Evaluating completed successfully!
# ==================================================
# Experiments:  20%|██        | 9/45 [06:01<19:50, 33.06s/it]
# Using device: cuda:0
# Loaded VAE checkpoint: experiments/vae-lstm-dual-ma/fold-0-batch-512/vae-lstm-dual-ma-144-24-1-12/checkpoint/vae_checkpoint_epoch_99.pth
# VAE_LSTM_MA(
#   (encoder): VAE_Encoder(
#     (local_module): LocalModule(
#       (enc_conv1): Sequential(
#         (0): Conv2d(55, 64, kernel_size=(3, 1), stride=(2, 1), padding=(1, 0))
#         (1): LeakyReLU(negative_slope=0.2)
#       )
#       (enc_conv2): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(3, 1), stride=(2, 1), padding=(1, 0))
#         (1): LeakyReLU(negative_slope=0.2)
#       )
#       (enc_conv3): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(3, 1), stride=(2, 1), padding=(1, 0))
#         (1): LeakyReLU(negative_slope=0.2)
#       )
#       (enc_conv4): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(4, 1), stride=(1, 1))
#         (1): LeakyReLU(negative_slope=0.2)
#       )
#       (enc_fc): Sequential(
#         (0): Linear(in_features=512, out_features=48, bias=True)
#         (1): LeakyReLU(negative_slope=0.2)
#       )
#     )
#     (global_module): GlobalModule(
#       (enc_conv1): Sequential(
#         (0): Conv1d(55, 64, kernel_size=(7,), stride=(3,), padding=(3,))
#         (1): LeakyReLU(negative_slope=0.2)
#         (2): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       )
#       (enc_conv2): Sequential(
#         (0): Conv1d(64, 128, kernel_size=(5,), stride=(3,), padding=(2,))
#         (1): LeakyReLU(negative_slope=0.2)
#         (2): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       )
#       (enc_conv3): Sequential(
#         (0): Conv1d(128, 256, kernel_size=(3,), stride=(2,), padding=(1,))
#         (1): Conv1d(256, 512, kernel_size=(3,), stride=(1,), padding=(1,))
#         (2): LeakyReLU(negative_slope=0.2)
#         (3): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       )
#       (enc_fc): Sequential(
#         (0): Linear(in_features=512, out_features=48, bias=True)
#         (1): LeakyReLU(negative_slope=0.2)
#       )
#     )
#     (ma): MA(
#       (ma_attn): MultiheadAttention(
#         (out_proj): NonDynamicallyQuantizableLinear(in_features=48, out_features=48, bias=True)
#       )
#       (ma_layernorm): LayerNorm((48,), eps=1e-05, elementwise_affine=True)
#     )
#     (fc_mean): Linear(in_features=48, out_features=12, bias=True)
#     (fc_log_var): Linear(in_features=48, out_features=12, bias=True)
#   )
#   (decoder): VAE_Decoder(
#     (dec_fc): Linear(in_features=12, out_features=512, bias=True)
#     (dec_conv1): Sequential(
#       (0): Conv2d(512, 384, kernel_size=(1, 1), stride=(1, 1))
#       (1): LeakyReLU(negative_slope=0.2)
#     )
#     (dec_conv2): Sequential(
#       (0): Conv2d(128, 128, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0))
#       (1): LeakyReLU(negative_slope=0.2)
#     )
#     (dec_conv3): Sequential(
#       (0): Conv2d(64, 64, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0))
#       (1): LeakyReLU(negative_slope=0.2)
#     )
#     (dec_conv4): Sequential(
#       (0): Conv2d(32, 32, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0))
#       (1): LeakyReLU(negative_slope=0.2)
#     )
#     (dec_out): Conv2d(16, 55, kernel_size=(5, 1), stride=(1, 1), padding=(2, 0))
#   )
#   (lstm): LSTMModel(
#     (lstm1): LSTM(12, 64, batch_first=True)
#     (lstm2): LSTM(64, 64, batch_first=True)
#     (lstm3): LSTM(64, 12, batch_first=True)
#   )
# )
# The model has 1,606,527 trainable parameters
# Evaluating on test set...
# Evaluating: 100%|███████████████████████████████| 85/85 [00:00<00:00, 87.52it/s]
# Test Set Inference Time: 491.53 ms
# Finding the theoretical best threshold based on F1 score...
# 101it [00:13,  7.40it/s]
# Threshold: 13709.020937500003
# Precision: 0.9081501684582063
# Recall: 0.8410846953937593
# Accuracy: 0.9241517888075387
# F1: 0.8733317904805987
# TP: 11321
# TN: 28692
# FP: 1145
# FN: 2139
# ==================================================
# Evaluating completed successfully!
# ==================================================
# Experiments:  22%|██▏       | 10/45 [06:18<16:25, 28.17s/it]
# Using device: cuda:0
# Loaded VAE checkpoint: experiments/vae-lstm-dual-ma/fold-1-batch-512/vae-lstm-dual-ma-144-24-1-12/checkpoint/vae_checkpoint_epoch_99.pth
# VAE_LSTM_MA(
#   (encoder): VAE_Encoder(
#     (local_module): LocalModule(
#       (enc_conv1): Sequential(
#         (0): Conv2d(55, 64, kernel_size=(3, 1), stride=(2, 1), padding=(1, 0))
#         (1): LeakyReLU(negative_slope=0.2)
#       )
#       (enc_conv2): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(3, 1), stride=(2, 1), padding=(1, 0))
#         (1): LeakyReLU(negative_slope=0.2)
#       )
#       (enc_conv3): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(3, 1), stride=(2, 1), padding=(1, 0))
#         (1): LeakyReLU(negative_slope=0.2)
#       )
#       (enc_conv4): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(4, 1), stride=(1, 1))
#         (1): LeakyReLU(negative_slope=0.2)
#       )
#       (enc_fc): Sequential(
#         (0): Linear(in_features=512, out_features=48, bias=True)
#         (1): LeakyReLU(negative_slope=0.2)
#       )
#     )
#     (global_module): GlobalModule(
#       (enc_conv1): Sequential(
#         (0): Conv1d(55, 64, kernel_size=(7,), stride=(3,), padding=(3,))
#         (1): LeakyReLU(negative_slope=0.2)
#         (2): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       )
#       (enc_conv2): Sequential(
#         (0): Conv1d(64, 128, kernel_size=(5,), stride=(3,), padding=(2,))
#         (1): LeakyReLU(negative_slope=0.2)
#         (2): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       )
#       (enc_conv3): Sequential(
#         (0): Conv1d(128, 256, kernel_size=(3,), stride=(2,), padding=(1,))
#         (1): Conv1d(256, 512, kernel_size=(3,), stride=(1,), padding=(1,))
#         (2): LeakyReLU(negative_slope=0.2)
#         (3): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       )
#       (enc_fc): Sequential(
#         (0): Linear(in_features=512, out_features=48, bias=True)
#         (1): LeakyReLU(negative_slope=0.2)
#       )
#     )
#     (ma): MA(
#       (ma_attn): MultiheadAttention(
#         (out_proj): NonDynamicallyQuantizableLinear(in_features=48, out_features=48, bias=True)
#       )
#       (ma_layernorm): LayerNorm((48,), eps=1e-05, elementwise_affine=True)
#     )
#     (fc_mean): Linear(in_features=48, out_features=12, bias=True)
#     (fc_log_var): Linear(in_features=48, out_features=12, bias=True)
#   )
#   (decoder): VAE_Decoder(
#     (dec_fc): Linear(in_features=12, out_features=512, bias=True)
#     (dec_conv1): Sequential(
#       (0): Conv2d(512, 384, kernel_size=(1, 1), stride=(1, 1))
#       (1): LeakyReLU(negative_slope=0.2)
#     )
#     (dec_conv2): Sequential(
#       (0): Conv2d(128, 128, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0))
#       (1): LeakyReLU(negative_slope=0.2)
#     )
#     (dec_conv3): Sequential(
#       (0): Conv2d(64, 64, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0))
#       (1): LeakyReLU(negative_slope=0.2)
#     )
#     (dec_conv4): Sequential(
#       (0): Conv2d(32, 32, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0))
#       (1): LeakyReLU(negative_slope=0.2)
#     )
#     (dec_out): Conv2d(16, 55, kernel_size=(5, 1), stride=(1, 1), padding=(2, 0))
#   )
#   (lstm): LSTMModel(
#     (lstm1): LSTM(12, 64, batch_first=True)
#     (lstm2): LSTM(64, 64, batch_first=True)
#     (lstm3): LSTM(64, 12, batch_first=True)
#   )
# )
# The model has 1,606,527 trainable parameters
# Evaluating on test set...
# Evaluating: 100%|███████████████████████████████| 87/87 [00:01<00:00, 77.34it/s]
# Test Set Inference Time: 501.62 ms
# Finding the theoretical best threshold based on F1 score...
# 101it [00:14,  6.99it/s]
# Threshold: 4556.9194531250005
# Precision: 0.9427047619047619
# Recall: 0.8737994350282486
# Accuracy: 0.9426771724651751
# F1: 0.9069452079897381
# TP: 12373
# TN: 29381
# FP: 752
# FN: 1787
# ==================================================
# Evaluating completed successfully!
# ==================================================
# Experiments:  24%|██▍       | 11/45 [06:36<14:13, 25.11s/it]
# Using device: cuda:0
# Loaded VAE checkpoint: experiments/vae-lstm-dual-ma/fold-2-batch-512/vae-lstm-dual-ma-144-24-1-12/checkpoint/vae_checkpoint_epoch_99.pth
# VAE_LSTM_MA(
#   (encoder): VAE_Encoder(
#     (local_module): LocalModule(
#       (enc_conv1): Sequential(
#         (0): Conv2d(55, 64, kernel_size=(3, 1), stride=(2, 1), padding=(1, 0))
#         (1): LeakyReLU(negative_slope=0.2)
#       )
#       (enc_conv2): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(3, 1), stride=(2, 1), padding=(1, 0))
#         (1): LeakyReLU(negative_slope=0.2)
#       )
#       (enc_conv3): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(3, 1), stride=(2, 1), padding=(1, 0))
#         (1): LeakyReLU(negative_slope=0.2)
#       )
#       (enc_conv4): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(4, 1), stride=(1, 1))
#         (1): LeakyReLU(negative_slope=0.2)
#       )
#       (enc_fc): Sequential(
#         (0): Linear(in_features=512, out_features=48, bias=True)
#         (1): LeakyReLU(negative_slope=0.2)
#       )
#     )
#     (global_module): GlobalModule(
#       (enc_conv1): Sequential(
#         (0): Conv1d(55, 64, kernel_size=(7,), stride=(3,), padding=(3,))
#         (1): LeakyReLU(negative_slope=0.2)
#         (2): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       )
#       (enc_conv2): Sequential(
#         (0): Conv1d(64, 128, kernel_size=(5,), stride=(3,), padding=(2,))
#         (1): LeakyReLU(negative_slope=0.2)
#         (2): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       )
#       (enc_conv3): Sequential(
#         (0): Conv1d(128, 256, kernel_size=(3,), stride=(2,), padding=(1,))
#         (1): Conv1d(256, 512, kernel_size=(3,), stride=(1,), padding=(1,))
#         (2): LeakyReLU(negative_slope=0.2)
#         (3): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       )
#       (enc_fc): Sequential(
#         (0): Linear(in_features=512, out_features=48, bias=True)
#         (1): LeakyReLU(negative_slope=0.2)
#       )
#     )
#     (ma): MA(
#       (ma_attn): MultiheadAttention(
#         (out_proj): NonDynamicallyQuantizableLinear(in_features=48, out_features=48, bias=True)
#       )
#       (ma_layernorm): LayerNorm((48,), eps=1e-05, elementwise_affine=True)
#     )
#     (fc_mean): Linear(in_features=48, out_features=12, bias=True)
#     (fc_log_var): Linear(in_features=48, out_features=12, bias=True)
#   )
#   (decoder): VAE_Decoder(
#     (dec_fc): Linear(in_features=12, out_features=512, bias=True)
#     (dec_conv1): Sequential(
#       (0): Conv2d(512, 384, kernel_size=(1, 1), stride=(1, 1))
#       (1): LeakyReLU(negative_slope=0.2)
#     )
#     (dec_conv2): Sequential(
#       (0): Conv2d(128, 128, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0))
#       (1): LeakyReLU(negative_slope=0.2)
#     )
#     (dec_conv3): Sequential(
# ...
#         (1): LeakyReLU(negative_slope=0.2)
#       )
#       (enc_conv3): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(3, 1), stride=(2, 1), padding=(1, 0))
#         (1): LeakyReLU(negative_slope=0.2)
#       )
#       (enc_conv4): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(4, 1), stride=(1, 1))
#         (1): LeakyReLU(negative_slope=0.2)
#       )
#       (enc_fc): Sequential(
#         (0): Linear(in_features=512, out_features=48, bias=True)
#         (1): LeakyReLU(negative_slope=0.2)
#       )
#     )
#     (fc_mean): Linear(in_features=48, out_features=12, bias=True)
#     (fc_log_var): Linear(in_features=48, out_features=12, bias=True)
#   )
#   (decoder): VAE_Decoder(
#     (dec_fc): Linear(in_features=12, out_features=512, bias=True)
#     (dec_conv1): Sequential(
#       (0): Conv2d(512, 384, kernel_size=(1, 1), stride=(1, 1))
#       (1): LeakyReLU(negative_slope=0.2)
#     )
#     (dec_conv2): Sequential(
#       (0): Conv2d(128, 128, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0))
#       (1): LeakyReLU(negative_slope=0.2)
#     )
#     (dec_conv3): Sequential(
#       (0): Conv2d(64, 64, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0))
#       (1): LeakyReLU(negative_slope=0.2)
#     )
#     (dec_conv4): Sequential(
#       (0): Conv2d(32, 32, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0))
#       (1): LeakyReLU(negative_slope=0.2)
#     )
#     (dec_out): Conv2d(16, 55, kernel_size=(5, 1), stride=(1, 1), padding=(2, 0))
#   )
#   (lstm): LSTMModel(
#     (lstm1): LSTM(12, 64, batch_first=True)
#     (lstm2): LSTM(64, 64, batch_first=True)
#     (lstm3): LSTM(64, 12, batch_first=True)
#   )
# )
# The model has 1,014,319 trainable parameters
# Evaluating on test set...
# Evaluating: 100%|███████████████████████████████| 85/85 [00:01<00:00, 59.89it/s]
# Test Set Inference Time: 731.20 ms
# Finding the theoretical best threshold based on F1 score...
# 101it [00:16,  5.97it/s]
# Threshold: 12990.599921875013
# Precision: 0.9145582410476113
# Recall: 0.8405646359583953
# Accuracy: 0.9260225881700811
# F1: 0.8760017033796601
# TP: 11314
# TN: 28780
# FP: 1057
# FN: 2146
# ==================================================
# Evaluating completed successfully!
# ==================================================
# Experiments:  89%|████████▉ | 40/45 [23:47<02:50, 34.16s/it]
# Using device: cuda:0
# Loaded VAE checkpoint: experiments/vae-lstm-local-only/fold-1-batch-512/vae-lstm-local-only-144-24-1-12/checkpoint/vae_checkpoint_epoch_99.pth
# VAE_LSTM_Local(
#   (encoder): VAE_Encoder_Local(
#     (local_module): LocalModule(
#       (enc_conv1): Sequential(
#         (0): Conv2d(55, 64, kernel_size=(3, 1), stride=(2, 1), padding=(1, 0))
#         (1): LeakyReLU(negative_slope=0.2)
#       )
#       (enc_conv2): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(3, 1), stride=(2, 1), padding=(1, 0))
#         (1): LeakyReLU(negative_slope=0.2)
#       )
#       (enc_conv3): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(3, 1), stride=(2, 1), padding=(1, 0))
#         (1): LeakyReLU(negative_slope=0.2)
#       )
#       (enc_conv4): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(4, 1), stride=(1, 1))
#         (1): LeakyReLU(negative_slope=0.2)
#       )
#       (enc_fc): Sequential(
#         (0): Linear(in_features=512, out_features=48, bias=True)
#         (1): LeakyReLU(negative_slope=0.2)
#       )
#     )
#     (fc_mean): Linear(in_features=48, out_features=12, bias=True)
#     (fc_log_var): Linear(in_features=48, out_features=12, bias=True)
#   )
#   (decoder): VAE_Decoder(
#     (dec_fc): Linear(in_features=12, out_features=512, bias=True)
#     (dec_conv1): Sequential(
#       (0): Conv2d(512, 384, kernel_size=(1, 1), stride=(1, 1))
#       (1): LeakyReLU(negative_slope=0.2)
#     )
#     (dec_conv2): Sequential(
#       (0): Conv2d(128, 128, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0))
#       (1): LeakyReLU(negative_slope=0.2)
#     )
#     (dec_conv3): Sequential(
#       (0): Conv2d(64, 64, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0))
#       (1): LeakyReLU(negative_slope=0.2)
#     )
#     (dec_conv4): Sequential(
#       (0): Conv2d(32, 32, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0))
#       (1): LeakyReLU(negative_slope=0.2)
#     )
#     (dec_out): Conv2d(16, 55, kernel_size=(5, 1), stride=(1, 1), padding=(2, 0))
#   )
#   (lstm): LSTMModel(
#     (lstm1): LSTM(12, 64, batch_first=True)
#     (lstm2): LSTM(64, 64, batch_first=True)
#     (lstm3): LSTM(64, 12, batch_first=True)
#   )
# )
# The model has 1,014,319 trainable parameters
# Evaluating on test set...
# Evaluating: 100%|███████████████████████████████| 87/87 [00:01<00:00, 57.52it/s]
# Test Set Inference Time: 683.82 ms
# Finding the theoretical best threshold based on F1 score...
# 101it [00:17,  5.73it/s]
# Threshold: 4191.877226562502
# Precision: 0.9394829612220916
# Recall: 0.9033898305084745
# Accuracy: 0.9505113674847041
# F1: 0.9210829493087557
# TP: 12792
# TN: 29309
# FP: 824
# FN: 1368
# ==================================================
# Evaluating completed successfully!
# ==================================================
# Experiments:  91%|█████████ | 41/45 [24:10<02:02, 30.69s/it]
# Using device: cuda:0
# Loaded VAE checkpoint: experiments/vae-lstm-local-only/fold-2-batch-512/vae-lstm-local-only-144-24-1-12/checkpoint/vae_checkpoint_epoch_99.pth
# VAE_LSTM_Local(
#   (encoder): VAE_Encoder_Local(
#     (local_module): LocalModule(
#       (enc_conv1): Sequential(
#         (0): Conv2d(55, 64, kernel_size=(3, 1), stride=(2, 1), padding=(1, 0))
#         (1): LeakyReLU(negative_slope=0.2)
#       )
#       (enc_conv2): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(3, 1), stride=(2, 1), padding=(1, 0))
#         (1): LeakyReLU(negative_slope=0.2)
#       )
#       (enc_conv3): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(3, 1), stride=(2, 1), padding=(1, 0))
#         (1): LeakyReLU(negative_slope=0.2)
#       )
#       (enc_conv4): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(4, 1), stride=(1, 1))
#         (1): LeakyReLU(negative_slope=0.2)
#       )
#       (enc_fc): Sequential(
#         (0): Linear(in_features=512, out_features=48, bias=True)
#         (1): LeakyReLU(negative_slope=0.2)
#       )
#     )
#     (fc_mean): Linear(in_features=48, out_features=12, bias=True)
#     (fc_log_var): Linear(in_features=48, out_features=12, bias=True)
#   )
#   (decoder): VAE_Decoder(
#     (dec_fc): Linear(in_features=12, out_features=512, bias=True)
#     (dec_conv1): Sequential(
#       (0): Conv2d(512, 384, kernel_size=(1, 1), stride=(1, 1))
#       (1): LeakyReLU(negative_slope=0.2)
#     )
#     (dec_conv2): Sequential(
#       (0): Conv2d(128, 128, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0))
#       (1): LeakyReLU(negative_slope=0.2)
#     )
#     (dec_conv3): Sequential(
#       (0): Conv2d(64, 64, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0))
#       (1): LeakyReLU(negative_slope=0.2)
#     )
#     (dec_conv4): Sequential(
#       (0): Conv2d(32, 32, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0))
#       (1): LeakyReLU(negative_slope=0.2)
#     )
#     (dec_out): Conv2d(16, 55, kernel_size=(5, 1), stride=(1, 1), padding=(2, 0))
#   )
#   (lstm): LSTMModel(
#     (lstm1): LSTM(12, 64, batch_first=True)
#     (lstm2): LSTM(64, 64, batch_first=True)
#     (lstm3): LSTM(64, 12, batch_first=True)
#   )
# )
# The model has 1,014,319 trainable parameters
# Evaluating on test set...
# Evaluating: 100%|███████████████████████████████| 88/88 [00:01<00:00, 58.69it/s]
# Test Set Inference Time: 824.88 ms
# Finding the theoretical best threshold based on F1 score...
# 101it [00:17,  5.78it/s]
# Threshold: 3167.7636328125013
# Precision: 0.7428618223508217
# Recall: 0.9541406633475913
# Accuracy: 0.8797012716140752
# F1: 0.8353490085333661
# TP: 13607
# TN: 25618
# FP: 4710
# FN: 654
# ==================================================
# Evaluating completed successfully!
# ==================================================
# Experiments:  93%|█████████▎| 42/45 [24:32<01:24, 28.21s/it]
# Using device: cuda:0
# Loaded VAE checkpoint: experiments/vae-lstm-local-only/fold-0-batch-512/vae-lstm-local-only-72-24-1-12/checkpoint/vae_checkpoint_epoch_99.pth
# VAE_LSTM_Local(
#   (encoder): VAE_Encoder_Local(
#     (local_module): LocalModule(
#       (enc_conv1): Sequential(
#         (0): Conv2d(55, 64, kernel_size=(3, 1), stride=(2, 1), padding=(1, 0))
#         (1): LeakyReLU(negative_slope=0.2)
#       )
#       (enc_conv2): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(3, 1), stride=(2, 1), padding=(1, 0))
#         (1): LeakyReLU(negative_slope=0.2)
#       )
#       (enc_conv3): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(3, 1), stride=(2, 1), padding=(1, 0))
#         (1): LeakyReLU(negative_slope=0.2)
#       )
#       (enc_conv4): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(4, 1), stride=(1, 1))
#         (1): LeakyReLU(negative_slope=0.2)
#       )
#       (enc_fc): Sequential(
#         (0): Linear(in_features=512, out_features=48, bias=True)
#         (1): LeakyReLU(negative_slope=0.2)
#       )
#     )
#     (fc_mean): Linear(in_features=48, out_features=12, bias=True)
#     (fc_log_var): Linear(in_features=48, out_features=12, bias=True)
#   )
#   (decoder): VAE_Decoder(
#     (dec_fc): Linear(in_features=12, out_features=512, bias=True)
#     (dec_conv1): Sequential(
#       (0): Conv2d(512, 384, kernel_size=(1, 1), stride=(1, 1))
#       (1): LeakyReLU(negative_slope=0.2)
#     )
#     (dec_conv2): Sequential(
#       (0): Conv2d(128, 128, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0))
#       (1): LeakyReLU(negative_slope=0.2)
#     )
#     (dec_conv3): Sequential(
#       (0): Conv2d(64, 64, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0))
#       (1): LeakyReLU(negative_slope=0.2)
#     )
#     (dec_conv4): Sequential(
#       (0): Conv2d(32, 32, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0))
#       (1): LeakyReLU(negative_slope=0.2)
#     )
#     (dec_out): Conv2d(16, 55, kernel_size=(5, 1), stride=(1, 1), padding=(2, 0))
#   )
#   (lstm): LSTMModel(
#     (lstm1): LSTM(12, 64, batch_first=True)
#     (lstm2): LSTM(64, 64, batch_first=True)
#     (lstm3): LSTM(64, 12, batch_first=True)
#   )
# )
# The model has 1,014,319 trainable parameters
# Evaluating on test set...
# Evaluating: 100%|███████████████████████████████| 85/85 [00:01<00:00, 79.89it/s]
# Test Set Inference Time: 606.63 ms
# Finding the theoretical best threshold based on F1 score...
# 101it [00:09, 11.12it/s]
# Threshold: 4985.455859375
# Precision: 0.9143108762659621
# Recall: 0.7925190839694657
# Accuracy: 0.9148931264267103
# F1: 0.8490697198936822
# TP: 10382
# TN: 29296
# FP: 973
# FN: 2718
# ==================================================
# Evaluating completed successfully!
# ==================================================
# Experiments:  96%|█████████▌| 43/45 [24:46<00:47, 23.80s/it]
# Using device: cuda:0
# Loaded VAE checkpoint: experiments/vae-lstm-local-only/fold-1-batch-512/vae-lstm-local-only-72-24-1-12/checkpoint/vae_checkpoint_epoch_99.pth
# VAE_LSTM_Local(
#   (encoder): VAE_Encoder_Local(
#     (local_module): LocalModule(
#       (enc_conv1): Sequential(
#         (0): Conv2d(55, 64, kernel_size=(3, 1), stride=(2, 1), padding=(1, 0))
#         (1): LeakyReLU(negative_slope=0.2)
#       )
#       (enc_conv2): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(3, 1), stride=(2, 1), padding=(1, 0))
#         (1): LeakyReLU(negative_slope=0.2)
#       )
#       (enc_conv3): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(3, 1), stride=(2, 1), padding=(1, 0))
#         (1): LeakyReLU(negative_slope=0.2)
#       )
#       (enc_conv4): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(4, 1), stride=(1, 1))
#         (1): LeakyReLU(negative_slope=0.2)
#       )
#       (enc_fc): Sequential(
#         (0): Linear(in_features=512, out_features=48, bias=True)
#         (1): LeakyReLU(negative_slope=0.2)
#       )
#     )
#     (fc_mean): Linear(in_features=48, out_features=12, bias=True)
#     (fc_log_var): Linear(in_features=48, out_features=12, bias=True)
#   )
#   (decoder): VAE_Decoder(
#     (dec_fc): Linear(in_features=12, out_features=512, bias=True)
#     (dec_conv1): Sequential(
#       (0): Conv2d(512, 384, kernel_size=(1, 1), stride=(1, 1))
#       (1): LeakyReLU(negative_slope=0.2)
#     )
#     (dec_conv2): Sequential(
#       (0): Conv2d(128, 128, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0))
#       (1): LeakyReLU(negative_slope=0.2)
#     )
#     (dec_conv3): Sequential(
#       (0): Conv2d(64, 64, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0))
#       (1): LeakyReLU(negative_slope=0.2)
#     )
#     (dec_conv4): Sequential(
#       (0): Conv2d(32, 32, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0))
#       (1): LeakyReLU(negative_slope=0.2)
#     )
#     (dec_out): Conv2d(16, 55, kernel_size=(5, 1), stride=(1, 1), padding=(2, 0))
#   )
#   (lstm): LSTMModel(
#     (lstm1): LSTM(12, 64, batch_first=True)
#     (lstm2): LSTM(64, 64, batch_first=True)
#     (lstm3): LSTM(64, 12, batch_first=True)
#   )
# )
# The model has 1,014,319 trainable parameters
# Evaluating on test set...
# Evaluating: 100%|███████████████████████████████| 87/87 [00:01<00:00, 79.08it/s]
# Test Set Inference Time: 637.24 ms
# Finding the theoretical best threshold based on F1 score...
# 101it [00:09, 10.32it/s]
# Threshold: 1868.3696289062505
# Precision: 0.8900800352448784
# Recall: 0.8784057971014493
# Accuracy: 0.9284345768060408
# F1: 0.8842043838214376
# TP: 12122
# TN: 29068
# FP: 1497
# FN: 1678
# ==================================================
# Evaluating completed successfully!
# ==================================================
# Experiments:  98%|█████████▊| 44/45 [25:00<00:20, 20.94s/it]
# Using device: cuda:0
# Loaded VAE checkpoint: experiments/vae-lstm-local-only/fold-2-batch-512/vae-lstm-local-only-72-24-1-12/checkpoint/vae_checkpoint_epoch_99.pth
# VAE_LSTM_Local(
#   (encoder): VAE_Encoder_Local(
#     (local_module): LocalModule(
#       (enc_conv1): Sequential(
#         (0): Conv2d(55, 64, kernel_size=(3, 1), stride=(2, 1), padding=(1, 0))
#         (1): LeakyReLU(negative_slope=0.2)
#       )
#       (enc_conv2): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(3, 1), stride=(2, 1), padding=(1, 0))
#         (1): LeakyReLU(negative_slope=0.2)
#       )
#       (enc_conv3): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(3, 1), stride=(2, 1), padding=(1, 0))
#         (1): LeakyReLU(negative_slope=0.2)
#       )
#       (enc_conv4): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(4, 1), stride=(1, 1))
#         (1): LeakyReLU(negative_slope=0.2)
#       )
#       (enc_fc): Sequential(
#         (0): Linear(in_features=512, out_features=48, bias=True)
#         (1): LeakyReLU(negative_slope=0.2)
#       )
#     )
#     (fc_mean): Linear(in_features=48, out_features=12, bias=True)
#     (fc_log_var): Linear(in_features=48, out_features=12, bias=True)
#   )
#   (decoder): VAE_Decoder(
#     (dec_fc): Linear(in_features=12, out_features=512, bias=True)
#     (dec_conv1): Sequential(
#       (0): Conv2d(512, 384, kernel_size=(1, 1), stride=(1, 1))
#       (1): LeakyReLU(negative_slope=0.2)
#     )
#     (dec_conv2): Sequential(
#       (0): Conv2d(128, 128, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0))
#       (1): LeakyReLU(negative_slope=0.2)
#     )
#     (dec_conv3): Sequential(
#       (0): Conv2d(64, 64, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0))
#       (1): LeakyReLU(negative_slope=0.2)
#     )
#     (dec_conv4): Sequential(
#       (0): Conv2d(32, 32, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0))
#       (1): LeakyReLU(negative_slope=0.2)
#     )
#     (dec_out): Conv2d(16, 55, kernel_size=(5, 1), stride=(1, 1), padding=(2, 0))
#   )
#   (lstm): LSTMModel(
#     (lstm1): LSTM(12, 64, batch_first=True)
#     (lstm2): LSTM(64, 64, batch_first=True)
#     (lstm3): LSTM(64, 12, batch_first=True)
#   )
# )
# The model has 1,014,319 trainable parameters
# Evaluating on test set...
# Evaluating: 100%|███████████████████████████████| 88/88 [00:01<00:00, 80.85it/s]
# Test Set Inference Time: 644.35 ms
# Finding the theoretical best threshold based on F1 score...
# 101it [00:09, 10.51it/s]
# Threshold: 1806.666333007812
# Precision: 0.8024723318879037
# Recall: 0.8873541830673441
# Accuracy: 0.8964196950359374
# F1: 0.8427814029363785
# TP: 12399
# TN: 27636
# FP: 3052
# FN: 1574
# ==================================================
# Evaluating completed successfully!
# ==================================================
# Experiments: 100%|██████████| 45/45 [25:14<00:00, 33.66s/it]

# %%
grid = {
    'exp_name': [
        'ma-vae',
    ],
    'window_size': [
        (576, 48),
        (288, 48),
        (288, 24),
        (144, 24),
        (72, 24)
    ],
    'fold_id': [0, 1, 2]
}
grid_prod = list(product(*grid.values()))
len(grid_prod)
# Out:
# 15

# %%
for exp_name, window_size, fold_id in tqdm(grid_prod, desc="Experiments"):
    with open('config.json', 'r', encoding='utf-8') as f:
        config = json.load(f)
    config['exp_name'] = exp_name
    config['window_size'] = window_size[0]
    config['small_window_size'] = window_size[0]
    config['window_shift'] = window_size[1]
    config['fold_id'] = fold_id
    config['latent_dim'] = 64
    config['batch_size'] = 64
    json.dump(config, open('config.json', 'w', encoding='utf-8'), indent=4)

    # !python test.py --config config.json
# Out:
# Experiments:   0%|          | 0/15 [00:00<?, ?it/s]
# Using device: cuda:0
# Loaded VAE checkpoint: experiments/ma-vae/fold-0-batch-64/ma-vae-576-576-48-64/checkpoint/vae_checkpoint_epoch_99.pth
# MA_VAE(
#   (encoder): MA_VAE_Encoder(
#     (bilstm1): LSTM(55, 512, batch_first=True, bidirectional=True)
#     (bilstm2): LSTM(1024, 256, batch_first=True, bidirectional=True)
#     (z_mean_layer): Linear(in_features=512, out_features=64, bias=True)
#     (z_log_var_layer): Linear(in_features=512, out_features=64, bias=True)
#   )
#   (decoder): MA_VAE_Decoder(
#     (bilstm1): LSTM(64, 256, batch_first=True, bidirectional=True)
#     (bilstm2): LSTM(512, 512, batch_first=True, bidirectional=True)
#     (Xhat_mean_layer): Linear(in_features=1024, out_features=55, bias=True)
#     (Xhat_log_var_layer): Linear(in_features=1024, out_features=55, bias=True)
#   )
#   (ma): MA_VAE_MA(
#     (q_k_projection): Linear(in_features=55, out_features=64, bias=True)
#     (attention_module): MultiheadAttention(
#       (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#     )
#     (output_projection): Linear(in_features=64, out_features=64, bias=True)
#   )
# )
# The model has 10,020,910 trainable parameters
# Evaluating on test set...
# Evaluating: 100%|███████████████████████████████| 14/14 [00:02<00:00,  6.40it/s]
# Test Set Inference Time: 2121.97 ms
# Finding the theoretical best threshold based on F1 score...
# 101it [00:02, 44.88it/s]
# Threshold: 70184.58203125
# Precision: 0.9538461538461539
# Recall: 0.7492447129909365
# Accuracy: 0.8937360178970917
# F1: 0.8392554991539762
# TP: 248
# TN: 551
# FP: 12
# FN: 83
# ==================================================
# Evaluating completed successfully!
# ==================================================
# Experiments:   7%|▋         | 1/15 [00:07<01:51,  7.95s/it]
# Using device: cuda:0
# Loaded VAE checkpoint: experiments/ma-vae/fold-1-batch-64/ma-vae-576-576-48-64/checkpoint/vae_checkpoint_epoch_99.pth
# MA_VAE(
#   (encoder): MA_VAE_Encoder(
#     (bilstm1): LSTM(55, 512, batch_first=True, bidirectional=True)
#     (bilstm2): LSTM(1024, 256, batch_first=True, bidirectional=True)
#     (z_mean_layer): Linear(in_features=512, out_features=64, bias=True)
#     (z_log_var_layer): Linear(in_features=512, out_features=64, bias=True)
#   )
#   (decoder): MA_VAE_Decoder(
#     (bilstm1): LSTM(64, 256, batch_first=True, bidirectional=True)
#     (bilstm2): LSTM(512, 512, batch_first=True, bidirectional=True)
#     (Xhat_mean_layer): Linear(in_features=1024, out_features=55, bias=True)
#     (Xhat_log_var_layer): Linear(in_features=1024, out_features=55, bias=True)
#   )
#   (ma): MA_VAE_MA(
#     (q_k_projection): Linear(in_features=55, out_features=64, bias=True)
#     (attention_module): MultiheadAttention(
#       (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#     )
#     (output_projection): Linear(in_features=64, out_features=64, bias=True)
#   )
# )
# The model has 10,020,910 trainable parameters
# Evaluating on test set...
# Evaluating: 100%|███████████████████████████████| 15/15 [00:02<00:00,  7.03it/s]
# Test Set Inference Time: 2062.28 ms
# Finding the theoretical best threshold based on F1 score...
# 101it [00:02, 42.10it/s]
# Threshold: 4131.1304931640625
# Precision: 0.990506329113924
# Recall: 0.9020172910662824
# Accuracy: 0.9595185995623632
# F1: 0.9441930618401206
# TP: 313
# TN: 564
# FP: 3
# FN: 34
# ==================================================
# Evaluating completed successfully!
# ==================================================
# Experiments:  13%|█▎        | 2/15 [00:15<01:41,  7.79s/it]
# Using device: cuda:0
# Loaded VAE checkpoint: experiments/ma-vae/fold-2-batch-64/ma-vae-576-576-48-64/checkpoint/vae_checkpoint_epoch_99.pth
# MA_VAE(
#   (encoder): MA_VAE_Encoder(
#     (bilstm1): LSTM(55, 512, batch_first=True, bidirectional=True)
#     (bilstm2): LSTM(1024, 256, batch_first=True, bidirectional=True)
#     (z_mean_layer): Linear(in_features=512, out_features=64, bias=True)
#     (z_log_var_layer): Linear(in_features=512, out_features=64, bias=True)
#   )
#   (decoder): MA_VAE_Decoder(
#     (bilstm1): LSTM(64, 256, batch_first=True, bidirectional=True)
#     (bilstm2): LSTM(512, 512, batch_first=True, bidirectional=True)
#     (Xhat_mean_layer): Linear(in_features=1024, out_features=55, bias=True)
#     (Xhat_log_var_layer): Linear(in_features=1024, out_features=55, bias=True)
#   )
#   (ma): MA_VAE_MA(
#     (q_k_projection): Linear(in_features=55, out_features=64, bias=True)
#     (attention_module): MultiheadAttention(
#       (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#     )
#     (output_projection): Linear(in_features=64, out_features=64, bias=True)
#   )
# )
# The model has 10,020,910 trainable parameters
# Evaluating on test set...
# Evaluating: 100%|███████████████████████████████| 15/15 [00:02<00:00,  6.44it/s]
# Test Set Inference Time: 2260.13 ms
# Finding the theoretical best threshold based on F1 score...
# 101it [00:02, 44.26it/s]
# Threshold: 6269.714658203125
# Precision: 0.6781857451403888
# Recall: 0.9289940828402367
# Accuracy: 0.8119565217391305
# F1: 0.7840199750312111
# TP: 314
# TN: 433
# FP: 149
# FN: 24
# ==================================================
# Evaluating completed successfully!
# ==================================================
# Experiments:  20%|██        | 3/15 [00:23<01:34,  7.91s/it]
# Using device: cuda:0
# Loaded VAE checkpoint: experiments/ma-vae/fold-0-batch-64/ma-vae-288-288-48-64/checkpoint/vae_checkpoint_epoch_99.pth
# MA_VAE(
#   (encoder): MA_VAE_Encoder(
#     (bilstm1): LSTM(55, 512, batch_first=True, bidirectional=True)
#     (bilstm2): LSTM(1024, 256, batch_first=True, bidirectional=True)
#     (z_mean_layer): Linear(in_features=512, out_features=64, bias=True)
#     (z_log_var_layer): Linear(in_features=512, out_features=64, bias=True)
#   )
#   (decoder): MA_VAE_Decoder(
#     (bilstm1): LSTM(64, 256, batch_first=True, bidirectional=True)
#     (bilstm2): LSTM(512, 512, batch_first=True, bidirectional=True)
#     (Xhat_mean_layer): Linear(in_features=1024, out_features=55, bias=True)
#     (Xhat_log_var_layer): Linear(in_features=1024, out_features=55, bias=True)
#   )
#   (ma): MA_VAE_MA(
#     (q_k_projection): Linear(in_features=55, out_features=64, bias=True)
#     (attention_module): MultiheadAttention(
#       (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#     )
#     (output_projection): Linear(in_features=64, out_features=64, bias=True)
#   )
# )
# The model has 10,020,910 trainable parameters
# Evaluating on test set...
# Evaluating: 100%|███████████████████████████████| 15/15 [00:00<00:00, 18.34it/s]
# Test Set Inference Time: 779.19 ms
# Finding the theoretical best threshold based on F1 score...
# 101it [00:01, 69.22it/s]
# Threshold: 23482.077695312506
# Precision: 0.8804347826086957
# Recall: 0.8073089700996677
# Accuracy: 0.8988888888888888
# F1: 0.8422876949740035
# TP: 243
# TN: 566
# FP: 33
# FN: 58
# ==================================================
# Evaluating completed successfully!
# ==================================================
# Experiments:  27%|██▋       | 4/15 [00:29<01:15,  6.90s/it]
# Using device: cuda:0
# Loaded VAE checkpoint: experiments/ma-vae/fold-1-batch-64/ma-vae-288-288-48-64/checkpoint/vae_checkpoint_epoch_99.pth
# MA_VAE(
#   (encoder): MA_VAE_Encoder(
#     (bilstm1): LSTM(55, 512, batch_first=True, bidirectional=True)
#     (bilstm2): LSTM(1024, 256, batch_first=True, bidirectional=True)
#     (z_mean_layer): Linear(in_features=512, out_features=64, bias=True)
#     (z_log_var_layer): Linear(in_features=512, out_features=64, bias=True)
#   )
#   (decoder): MA_VAE_Decoder(
#     (bilstm1): LSTM(64, 256, batch_first=True, bidirectional=True)
#     (bilstm2): LSTM(512, 512, batch_first=True, bidirectional=True)
#     (Xhat_mean_layer): Linear(in_features=1024, out_features=55, bias=True)
#     (Xhat_log_var_layer): Linear(in_features=1024, out_features=55, bias=True)
#   )
#   (ma): MA_VAE_MA(
#     (q_k_projection): Linear(in_features=55, out_features=64, bias=True)
#     (attention_module): MultiheadAttention(
#       (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#     )
#     (output_projection): Linear(in_features=64, out_features=64, bias=True)
#   )
# )
# The model has 10,020,910 trainable parameters
# Evaluating on test set...
# Evaluating: 100%|███████████████████████████████| 15/15 [00:00<00:00, 15.24it/s]
# Test Set Inference Time: 935.37 ms
# Finding the theoretical best threshold based on F1 score...
# 101it [00:01, 59.76it/s]
# Threshold: 2169.993505859376
# Precision: 0.916083916083916
# Recall: 0.8264984227129337
# Accuracy: 0.9141304347826087
# F1: 0.8689883913764511
# TP: 262
# TN: 579
# FP: 24
# FN: 55
# ==================================================
# Evaluating completed successfully!
# ==================================================
# Experiments:  33%|███▎      | 5/15 [00:34<01:04,  6.46s/it]
# Using device: cuda:0
# Loaded VAE checkpoint: experiments/ma-vae/fold-2-batch-64/ma-vae-288-288-48-64/checkpoint/vae_checkpoint_epoch_99.pth
# MA_VAE(
#   (encoder): MA_VAE_Encoder(
#     (bilstm1): LSTM(55, 512, batch_first=True, bidirectional=True)
#     (bilstm2): LSTM(1024, 256, batch_first=True, bidirectional=True)
#     (z_mean_layer): Linear(in_features=512, out_features=64, bias=True)
#     (z_log_var_layer): Linear(in_features=512, out_features=64, bias=True)
#   )
#   (decoder): MA_VAE_Decoder(
#     (bilstm1): LSTM(64, 256, batch_first=True, bidirectional=True)
#     (bilstm2): LSTM(512, 512, batch_first=True, bidirectional=True)
#     (Xhat_mean_layer): Linear(in_features=1024, out_features=55, bias=True)
#     (Xhat_log_var_layer): Linear(in_features=1024, out_features=55, bias=True)
#   )
#   (ma): MA_VAE_MA(
#     (q_k_projection): Linear(in_features=55, out_features=64, bias=True)
#     (attention_module): MultiheadAttention(
#       (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#     )
#     (output_projection): Linear(in_features=64, out_features=64, bias=True)
#   )
# )
# The model has 10,020,910 trainable parameters
# Evaluating on test set...
# Evaluating: 100%|███████████████████████████████| 15/15 [00:01<00:00, 11.66it/s]
# Test Set Inference Time: 1244.67 ms
# Finding the theoretical best threshold based on F1 score...
# 101it [00:01, 64.50it/s]
# Threshold: 4111.3876953125
# Precision: 0.7882736156351792
# Recall: 0.7707006369426752
# Accuracy: 0.8520518358531317
# F1: 0.7793880837359098
# TP: 242
# TN: 547
# FP: 65
# FN: 72
# ==================================================
# Evaluating completed successfully!
# ==================================================
# Experiments:  40%|████      | 6/15 [00:40<00:57,  6.35s/it]
# Using device: cuda:0
# Loaded VAE checkpoint: experiments/ma-vae/fold-0-batch-64/ma-vae-288-288-24-64/checkpoint/vae_checkpoint_epoch_99.pth
# MA_VAE(
#   (encoder): MA_VAE_Encoder(
#     (bilstm1): LSTM(55, 512, batch_first=True, bidirectional=True)
#     (bilstm2): LSTM(1024, 256, batch_first=True, bidirectional=True)
#     (z_mean_layer): Linear(in_features=512, out_features=64, bias=True)
#     (z_log_var_layer): Linear(in_features=512, out_features=64, bias=True)
#   )
#   (decoder): MA_VAE_Decoder(
#     (bilstm1): LSTM(64, 256, batch_first=True, bidirectional=True)
#     (bilstm2): LSTM(512, 512, batch_first=True, bidirectional=True)
#     (Xhat_mean_layer): Linear(in_features=1024, out_features=55, bias=True)
#     (Xhat_log_var_layer): Linear(in_features=1024, out_features=55, bias=True)
#   )
#   (ma): MA_VAE_MA(
#     (q_k_projection): Linear(in_features=55, out_features=64, bias=True)
#     (attention_module): MultiheadAttention(
#       (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#     )
#     (output_projection): Linear(in_features=64, out_features=64, bias=True)
#   )
# )
# The model has 10,020,910 trainable parameters
# Evaluating on test set...
# Evaluating: 100%|███████████████████████████████| 29/29 [00:02<00:00, 13.04it/s]
# Test Set Inference Time: 2150.03 ms
# Finding the theoretical best threshold based on F1 score...
# 101it [00:02, 49.24it/s]
# Threshold: 4376.049365234375
# Precision: 0.6765714285714286
# Recall: 0.9932885906040269
# Accuracy: 0.8404669260700389
# F1: 0.804894629503739
# TP: 592
# TN: 920
# FP: 283
# FN: 4
# ==================================================
# Evaluating completed successfully!
# ==================================================
# Experiments:  47%|████▋     | 7/15 [00:48<00:53,  6.74s/it]
# Using device: cuda:0
# Loaded VAE checkpoint: experiments/ma-vae/fold-1-batch-64/ma-vae-288-288-24-64/checkpoint/vae_checkpoint_epoch_99.pth
# MA_VAE(
#   (encoder): MA_VAE_Encoder(
#     (bilstm1): LSTM(55, 512, batch_first=True, bidirectional=True)
#     (bilstm2): LSTM(1024, 256, batch_first=True, bidirectional=True)
#     (z_mean_layer): Linear(in_features=512, out_features=64, bias=True)
#     (z_log_var_layer): Linear(in_features=512, out_features=64, bias=True)
#   )
#   (decoder): MA_VAE_Decoder(
#     (bilstm1): LSTM(64, 256, batch_first=True, bidirectional=True)
#     (bilstm2): LSTM(512, 512, batch_first=True, bidirectional=True)
#     (Xhat_mean_layer): Linear(in_features=1024, out_features=55, bias=True)
#     (Xhat_log_var_layer): Linear(in_features=1024, out_features=55, bias=True)
#   )
#   (ma): MA_VAE_MA(
#     (q_k_projection): Linear(in_features=55, out_features=64, bias=True)
#     (attention_module): MultiheadAttention(
#       (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#     )
#     (output_projection): Linear(in_features=64, out_features=64, bias=True)
#   )
# )
# The model has 10,020,910 trainable parameters
# Evaluating on test set...
# Evaluating: 100%|███████████████████████████████| 29/29 [00:02<00:00, 13.42it/s]
# Test Set Inference Time: 2090.20 ms
# Finding the theoretical best threshold based on F1 score...
# 101it [00:02, 45.18it/s]
# Threshold: 2289.1959472656245
# Precision: 0.8517964071856288
# Recall: 0.9089456869009584
# Accuracy: 0.9152173913043479
# F1: 0.8794435857805255
# TP: 569
# TN: 1115
# FP: 99
# FN: 57
# ==================================================
# Evaluating completed successfully!
# ==================================================
# Experiments:  53%|█████▎    | 8/15 [00:55<00:49,  7.01s/it]
# Using device: cuda:0
# Loaded VAE checkpoint: experiments/ma-vae/fold-2-batch-64/ma-vae-288-288-24-64/checkpoint/vae_checkpoint_epoch_99.pth
# MA_VAE(
#   (encoder): MA_VAE_Encoder(
#     (bilstm1): LSTM(55, 512, batch_first=True, bidirectional=True)
#     (bilstm2): LSTM(1024, 256, batch_first=True, bidirectional=True)
#     (z_mean_layer): Linear(in_features=512, out_features=64, bias=True)
#     (z_log_var_layer): Linear(in_features=512, out_features=64, bias=True)
#   )
#   (decoder): MA_VAE_Decoder(
#     (bilstm1): LSTM(64, 256, batch_first=True, bidirectional=True)
#     (bilstm2): LSTM(512, 512, batch_first=True, bidirectional=True)
#     (Xhat_mean_layer): Linear(in_features=1024, out_features=55, bias=True)
#     (Xhat_log_var_layer): Linear(in_features=1024, out_features=55, bias=True)
#   )
#   (ma): MA_VAE_MA(
#     (q_k_projection): Linear(in_features=55, out_features=64, bias=True)
#     (attention_module): MultiheadAttention(
#       (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#     )
#     (output_projection): Linear(in_features=64, out_features=64, bias=True)
#   )
# )
# The model has 10,020,910 trainable parameters
# Evaluating on test set...
# Evaluating: 100%|███████████████████████████████| 29/29 [00:02<00:00, 13.71it/s]
# Test Set Inference Time: 2047.76 ms
# Finding the theoretical best threshold based on F1 score...
# 101it [00:02, 47.11it/s]
# Threshold: 2535.849140625
# Precision: 0.7067371202113606
# Recall: 0.860128617363344
# Accuracy: 0.8331533477321814
# F1: 0.775924583031182
# TP: 535
# TN: 1008
# FP: 222
# FN: 87
# ==================================================
# Evaluating completed successfully!
# ==================================================
# Experiments:  60%|██████    | 9/15 [01:03<00:42,  7.13s/it]
# Using device: cuda:0
# Loaded VAE checkpoint: experiments/ma-vae/fold-0-batch-64/ma-vae-144-144-24-64/checkpoint/vae_checkpoint_epoch_99.pth
# MA_VAE(
#   (encoder): MA_VAE_Encoder(
#     (bilstm1): LSTM(55, 512, batch_first=True, bidirectional=True)
#     (bilstm2): LSTM(1024, 256, batch_first=True, bidirectional=True)
#     (z_mean_layer): Linear(in_features=512, out_features=64, bias=True)
#     (z_log_var_layer): Linear(in_features=512, out_features=64, bias=True)
#   )
#   (decoder): MA_VAE_Decoder(
#     (bilstm1): LSTM(64, 256, batch_first=True, bidirectional=True)
#     (bilstm2): LSTM(512, 512, batch_first=True, bidirectional=True)
#     (Xhat_mean_layer): Linear(in_features=1024, out_features=55, bias=True)
#     (Xhat_log_var_layer): Linear(in_features=1024, out_features=55, bias=True)
#   )
#   (ma): MA_VAE_MA(
#     (q_k_projection): Linear(in_features=55, out_features=64, bias=True)
#     (attention_module): MultiheadAttention(
#       (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#     )
#     (output_projection): Linear(in_features=64, out_features=64, bias=True)
#   )
# )
# The model has 10,020,910 trainable parameters
# Evaluating on test set...
# Evaluating: 100%|███████████████████████████████| 29/29 [00:01<00:00, 24.59it/s]
# Test Set Inference Time: 1131.49 ms
# Finding the theoretical best threshold based on F1 score...
# 101it [00:01, 70.12it/s]
# Threshold: 1687.0588378906243
# Precision: 0.6662606577344702
# Recall: 0.9664310954063604
# Accuracy: 0.8376731301939058
# F1: 0.7887527036770008
# TP: 547
# TN: 965
# FP: 274
# FN: 19
# ==================================================
# Evaluating completed successfully!
# ==================================================
# Experiments:  67%|██████▋   | 10/15 [01:09<00:33,  6.69s/it]
# Using device: cuda:0
# Loaded VAE checkpoint: experiments/ma-vae/fold-1-batch-64/ma-vae-144-144-24-64/checkpoint/vae_checkpoint_epoch_99.pth
# MA_VAE(
#   (encoder): MA_VAE_Encoder(
#     (bilstm1): LSTM(55, 512, batch_first=True, bidirectional=True)
#     (bilstm2): LSTM(1024, 256, batch_first=True, bidirectional=True)
#     (z_mean_layer): Linear(in_features=512, out_features=64, bias=True)
#     (z_log_var_layer): Linear(in_features=512, out_features=64, bias=True)
#   )
#   (decoder): MA_VAE_Decoder(
#     (bilstm1): LSTM(64, 256, batch_first=True, bidirectional=True)
#     (bilstm2): LSTM(512, 512, batch_first=True, bidirectional=True)
#     (Xhat_mean_layer): Linear(in_features=1024, out_features=55, bias=True)
#     (Xhat_log_var_layer): Linear(in_features=1024, out_features=55, bias=True)
#   )
#   (ma): MA_VAE_MA(
#     (q_k_projection): Linear(in_features=55, out_features=64, bias=True)
#     (attention_module): MultiheadAttention(
#       (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#     )
#     (output_projection): Linear(in_features=64, out_features=64, bias=True)
#   )
# )
# The model has 10,020,910 trainable parameters
# Evaluating on test set...
# Evaluating: 100%|███████████████████████████████| 29/29 [00:01<00:00, 23.68it/s]
# Test Set Inference Time: 1172.81 ms
# Finding the theoretical best threshold based on F1 score...
# 101it [00:01, 63.38it/s]
# Threshold: 1053.6444702148438
# Precision: 0.8321299638989169
# Recall: 0.7734899328859061
# Accuracy: 0.8764897074756229
# F1: 0.8017391304347826
# TP: 461
# TN: 1157
# FP: 93
# FN: 135
# ==================================================
# Evaluating completed successfully!
# ==================================================
# Experiments:  73%|███████▎  | 11/15 [01:14<00:25,  6.44s/it]
# Using device: cuda:0
# Loaded VAE checkpoint: experiments/ma-vae/fold-2-batch-64/ma-vae-144-144-24-64/checkpoint/vae_checkpoint_epoch_99.pth
# MA_VAE(
#   (encoder): MA_VAE_Encoder(
#     (bilstm1): LSTM(55, 512, batch_first=True, bidirectional=True)
#     (bilstm2): LSTM(1024, 256, batch_first=True, bidirectional=True)
#     (z_mean_layer): Linear(in_features=512, out_features=64, bias=True)
#     (z_log_var_layer): Linear(in_features=512, out_features=64, bias=True)
#   )
#   (decoder): MA_VAE_Decoder(
#     (bilstm1): LSTM(64, 256, batch_first=True, bidirectional=True)
#     (bilstm2): LSTM(512, 512, batch_first=True, bidirectional=True)
#     (Xhat_mean_layer): Linear(in_features=1024, out_features=55, bias=True)
#     (Xhat_log_var_layer): Linear(in_features=1024, out_features=55, bias=True)
#   )
#   (ma): MA_VAE_MA(
#     (q_k_projection): Linear(in_features=55, out_features=64, bias=True)
#     (attention_module): MultiheadAttention(
#       (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#     )
#     (output_projection): Linear(in_features=64, out_features=64, bias=True)
#   )
# )
# The model has 10,020,910 trainable parameters
# Evaluating on test set...
# Evaluating: 100%|███████████████████████████████| 30/30 [00:01<00:00, 24.20it/s]
# Test Set Inference Time: 1189.65 ms
# Finding the theoretical best threshold based on F1 score...
# 101it [00:01, 66.17it/s]
# Threshold: 1277.475480957031
# Precision: 0.7025495750708215
# Recall: 0.8294314381270903
# Accuracy: 0.8320775026910656
# F1: 0.7607361963190185
# TP: 496
# TN: 1050
# FP: 210
# FN: 102
# ==================================================
# Evaluating completed successfully!
# ==================================================
# Experiments:  80%|████████  | 12/15 [01:20<00:18,  6.25s/it]
# Using device: cuda:0
# Loaded VAE checkpoint: experiments/ma-vae/fold-0-batch-64/ma-vae-72-72-24-64/checkpoint/vae_checkpoint_epoch_99.pth
# MA_VAE(
#   (encoder): MA_VAE_Encoder(
#     (bilstm1): LSTM(55, 512, batch_first=True, bidirectional=True)
#     (bilstm2): LSTM(1024, 256, batch_first=True, bidirectional=True)
#     (z_mean_layer): Linear(in_features=512, out_features=64, bias=True)
#     (z_log_var_layer): Linear(in_features=512, out_features=64, bias=True)
#   )
#   (decoder): MA_VAE_Decoder(
#     (bilstm1): LSTM(64, 256, batch_first=True, bidirectional=True)
#     (bilstm2): LSTM(512, 512, batch_first=True, bidirectional=True)
#     (Xhat_mean_layer): Linear(in_features=1024, out_features=55, bias=True)
#     (Xhat_log_var_layer): Linear(in_features=1024, out_features=55, bias=True)
#   )
#   (ma): MA_VAE_MA(
#     (q_k_projection): Linear(in_features=55, out_features=64, bias=True)
#     (attention_module): MultiheadAttention(
#       (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#     )
#     (output_projection): Linear(in_features=64, out_features=64, bias=True)
#   )
# )
# The model has 10,020,910 trainable parameters
# Evaluating on test set...
# Evaluating: 100%|███████████████████████████████| 29/29 [00:00<00:00, 36.79it/s]
# Test Set Inference Time: 748.64 ms
# Finding the theoretical best threshold based on F1 score...
# 101it [00:01, 83.35it/s]
# Threshold: 819.9912463378911
# Precision: 0.6530880420499343
# Recall: 0.9019963702359347
# Accuracy: 0.8241150442477876
# F1: 0.7576219512195123
# TP: 497
# TN: 993
# FP: 264
# FN: 54
# ==================================================
# Evaluating completed successfully!
# ==================================================
# Experiments:  87%|████████▋ | 13/15 [01:25<00:11,  5.91s/it]
# Using device: cuda:0
# Loaded VAE checkpoint: experiments/ma-vae/fold-1-batch-64/ma-vae-72-72-24-64/checkpoint/vae_checkpoint_epoch_99.pth
# MA_VAE(
#   (encoder): MA_VAE_Encoder(
#     (bilstm1): LSTM(55, 512, batch_first=True, bidirectional=True)
#     (bilstm2): LSTM(1024, 256, batch_first=True, bidirectional=True)
#     (z_mean_layer): Linear(in_features=512, out_features=64, bias=True)
#     (z_log_var_layer): Linear(in_features=512, out_features=64, bias=True)
#   )
#   (decoder): MA_VAE_Decoder(
#     (bilstm1): LSTM(64, 256, batch_first=True, bidirectional=True)
#     (bilstm2): LSTM(512, 512, batch_first=True, bidirectional=True)
#     (Xhat_mean_layer): Linear(in_features=1024, out_features=55, bias=True)
#     (Xhat_log_var_layer): Linear(in_features=1024, out_features=55, bias=True)
#   )
#   (ma): MA_VAE_MA(
#     (q_k_projection): Linear(in_features=55, out_features=64, bias=True)
#     (attention_module): MultiheadAttention(
#       (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#     )
#     (output_projection): Linear(in_features=64, out_features=64, bias=True)
#   )
# )
# The model has 10,020,910 trainable parameters
# Evaluating on test set...
# Evaluating: 100%|███████████████████████████████| 29/29 [00:00<00:00, 37.43it/s]
# Test Set Inference Time: 723.43 ms
# Finding the theoretical best threshold based on F1 score...
# 101it [00:01, 76.46it/s]
# Threshold: 484.5743994140625
# Precision: 0.9096509240246407
# Recall: 0.7624784853700516
# Accuracy: 0.9015684153596538
# F1: 0.8295880149812732
# TP: 443
# TN: 1224
# FP: 44
# FN: 138
# ==================================================
# Evaluating completed successfully!
# ==================================================
# Experiments:  93%|█████████▎| 14/15 [01:31<00:05,  5.69s/it]
# Using device: cuda:0
# Loaded VAE checkpoint: experiments/ma-vae/fold-2-batch-64/ma-vae-72-72-24-64/checkpoint/vae_checkpoint_epoch_99.pth
# MA_VAE(
#   (encoder): MA_VAE_Encoder(
#     (bilstm1): LSTM(55, 512, batch_first=True, bidirectional=True)
#     (bilstm2): LSTM(1024, 256, batch_first=True, bidirectional=True)
#     (z_mean_layer): Linear(in_features=512, out_features=64, bias=True)
#     (z_log_var_layer): Linear(in_features=512, out_features=64, bias=True)
#   )
#   (decoder): MA_VAE_Decoder(
#     (bilstm1): LSTM(64, 256, batch_first=True, bidirectional=True)
#     (bilstm2): LSTM(512, 512, batch_first=True, bidirectional=True)
#     (Xhat_mean_layer): Linear(in_features=1024, out_features=55, bias=True)
#     (Xhat_log_var_layer): Linear(in_features=1024, out_features=55, bias=True)
#   )
#   (ma): MA_VAE_MA(
#     (q_k_projection): Linear(in_features=55, out_features=64, bias=True)
#     (attention_module): MultiheadAttention(
#       (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#     )
#     (output_projection): Linear(in_features=64, out_features=64, bias=True)
#   )
# )
# The model has 10,020,910 trainable parameters
# Evaluating on test set...
# Evaluating: 100%|███████████████████████████████| 30/30 [00:00<00:00, 38.59it/s]
# Test Set Inference Time: 729.66 ms
# Finding the theoretical best threshold based on F1 score...
# 101it [00:01, 74.78it/s]
# Threshold: 404.26584472656253
# Precision: 0.6922024623803009
# Recall: 0.863481228668942
# Accuracy: 0.8361096184846857
# F1: 0.768413059984814
# TP: 506
# TN: 1050
# FP: 225
# FN: 80
# ==================================================
# Evaluating completed successfully!
# ==================================================
# Experiments: 100%|██████████| 15/15 [01:36<00:00,  6.43s/it]
